# %%
import numpy as np
import matplotlib.pyplot as plt
import math as math

# %%
np.set_printoptions(suppress=True)
X = 2*np.round(np.random.rand(1000,10),decimals=3)-1
# print(X)
# Y=np.add(X[:,0:1],X[:,1:2],3*X[:,2:3]*X[:,3:4],X[:,4:5],X[:,5:6],6*X[:,5:6],7*X[:,7:8],7*X[:,8:9],8*X[:9:10])
# Y= np.add(np.add(np.add(X[:,0:1],3*X[:,1:2].*X[:,1:2],X[:,2:3]),np.add(X[:,3:4],6*X[:,4:5],7*X[:,5:6]),np.add(7*X[:,6:7],8*exp(X[:,7:8]),5*X[:,8:9])),X[:,9:10])
y1= np.add(X[:,0:1],3*X[:,1:2]*X[:,1:2],X[:,2:3])
y2 = np.add(X[:,3:4],6*X[:,4:5],7*X[:,5:6])
y3 = np.add(7*X[:,6:7],8*np.exp(X[:,7:8]),5*X[:,8:9])
y4 = X[:,9:10]
Y=np.round(np.add(np.add(y1,y2),np.add(y3,y4)),decimals=3)
# print(Y)
print(np.amax(Y))
# Out:
# 32.371

# %%
def print_network(net):
    for i,layer in enumerate(net,1):
        print("Layer {} ".format(i))
        for j,neuron in enumerate(layer,1):
            print("neuron {} :".format(j),neuron)

# %%
def initialize_network():
    
    input_neurons=len(X[0])
    hidden_neurons=input_neurons+1
    output_neurons=1
    
    n_hidden_layers=1
    
    net=list()
    
    for h in range(n_hidden_layers):
        if h!=0:
            input_neurons=len(net[-1])
            
        hidden_layer = [ { 'weights': np.random.uniform(size=input_neurons)} for i in range(hidden_neurons) ]
        net.append(hidden_layer)
    
    output_layer = [ { 'weights': np.random.uniform(size=hidden_neurons)} for i in range(output_neurons)]
    net.append(output_layer)
    
    return net

# %%
net=initialize_network()

# %%
def activate_sigmoid(sum):
    return (2/(1+np.exp(-sum))-1)

# %%
def forward_propagation(net,input):
    row=input
    for layer in net:
        prev_input=np.array([])
        for neuron in layer:
            sum=neuron['weights'].T.dot(row)
            
            result=activate_sigmoid(sum)
            neuron['result']=result
            prev_input=np.append(prev_input,[result])
        row =prev_input
    return row

# %%
def sigmoidDerivative(output):
    return (0.5*(1.0-output*output))

# %%
def back_propagation(net,row,expected):
     for i in reversed(range(len(net))):
            layer=net[i]
            errors=np.array([])
            if i==len(net)-1:
                results=[neuron['result'] for neuron in layer]
                errors = expected-np.array(results) 
            else:
                for j in range(len(layer)):
                    herror=0
                    nextlayer=net[i+1]
                    for neuron in nextlayer:
                        herror+=(neuron['weights'][j]*neuron['delta'])
                    errors=np.append(errors,[herror])
            
            for j in range(len(layer)):
                neuron=layer[j]
                neuron['delta']=errors[j]*sigmoidDerivative(neuron['result'])

# %%
def updateWeights(net,input,lrate):
    
    for i in range(len(net)):
        inputs = input
        if i!=0:
            inputs=[neuron['result'] for neuron in net[i-1]]

        for neuron in net[i]:
            for j in range(len(inputs)):
                neuron['weights'][j]+=lrate*neuron['delta']*inputs[j]

# %%
def training(net, epochs,lrate,n_outputs):
    errors=[]
    for epoch in range(epochs):
        sum_error=0
        for i,row in enumerate(X):
            outputs=forward_propagation(net,row)
#             expected = [0 for i in range(n_outputs)]
#             expected[row[-1]] = 1    
            sum_error=Y[i]-outputs
#             print(sum_error)
            back_propagation(net,row,Y[i])
            updateWeights(net,row,0.05)
            print('>epoch=%d,error=%.3f'%(epoch,sum_error))
            errors.append(sum_error)
    return errors

# %%
errors=training(net,10000, 0.05,1)
# Out:
# >epoch=0,error=13.458
# >epoch=0,error=18.319
# >epoch=0,error=6.840
# >epoch=0,error=4.990
# >epoch=0,error=13.107
# >epoch=0,error=6.889
# >epoch=0,error=6.183
# >epoch=0,error=10.106
# >epoch=0,error=13.474
# >epoch=0,error=23.008
# >epoch=0,error=8.848
# >epoch=0,error=4.649
# >epoch=0,error=16.157
# >epoch=0,error=15.381
# >epoch=0,error=21.336
# >epoch=0,error=8.065
# >epoch=0,error=9.496
# >epoch=0,error=5.467
# >epoch=0,error=14.086
# >epoch=0,error=6.043
# >epoch=0,error=17.279
# >epoch=0,error=9.110
# >epoch=0,error=20.093
# >epoch=0,error=7.672
# >epoch=0,error=9.195
# >epoch=0,error=-2.551
# >epoch=0,error=10.304
# >epoch=0,error=25.079
# >epoch=0,error=3.909
# >epoch=0,error=9.575
# >epoch=0,error=8.903
# >epoch=0,error=20.917
# >epoch=0,error=-0.084
# >epoch=0,error=6.389
# >epoch=0,error=4.864
# >epoch=0,error=7.714
# >epoch=0,error=9.956
# >epoch=0,error=18.340
# >epoch=0,error=6.674
# >epoch=0,error=10.806
# >epoch=0,error=11.172
# >epoch=0,error=7.412
# >epoch=0,error=12.750
# >epoch=0,error=15.205
# >epoch=0,error=9.551
# >epoch=0,error=13.697
# >epoch=0,error=7.843
# >epoch=0,error=0.064
# >epoch=0,error=13.647
# >epoch=0,error=3.989
# >epoch=0,error=3.620
# >epoch=0,error=15.085
# >epoch=0,error=0.675
# >epoch=0,error=8.021
# >epoch=0,error=-0.122
# >epoch=0,error=4.877
# >epoch=0,error=13.648
# >epoch=0,error=17.263
# >epoch=0,error=25.561
# >epoch=0,error=8.632
# >epoch=0,error=19.321
# >epoch=0,error=9.750
# >epoch=0,error=13.856
# >epoch=0,error=4.914
# >epoch=0,error=16.987
# >epoch=0,error=19.555
# >epoch=0,error=4.320
# >epoch=0,error=2.342
# >epoch=0,error=17.198
# >epoch=0,error=5.388
# >epoch=0,error=15.436
# >epoch=0,error=6.963
# >epoch=0,error=11.543
# >epoch=0,error=16.034
# >epoch=0,error=1.853
# >epoch=0,error=6.627
# >epoch=0,error=-6.665
# >epoch=0,error=15.791
# >epoch=0,error=2.390
# >epoch=0,error=16.080
# >epoch=0,error=-1.012
# >epoch=0,error=6.411
# >epoch=0,error=-1.734
# >epoch=0,error=10.234
# >epoch=0,error=8.939
# >epoch=0,error=22.409
# >epoch=0,error=8.163
# >epoch=0,error=6.592
# >epoch=0,error=11.784
# >epoch=0,error=12.167
# >epoch=0,error=0.183
# >epoch=0,error=29.079
# >epoch=0,error=6.579
# >epoch=0,error=17.320
# >epoch=0,error=14.394
# >epoch=0,error=1.539
# >epoch=0,error=0.614
# >epoch=0,error=0.468
# >epoch=0,error=24.829
# >epoch=0,error=8.919
# >epoch=0,error=7.697
# >epoch=0,error=1.143
# >epoch=0,error=13.807
# >epoch=0,error=22.685
# >epoch=0,error=16.195
# >epoch=0,error=0.080
# >epoch=0,error=6.602
# >epoch=0,error=22.170
# >epoch=0,error=20.138
# >epoch=0,error=7.989
# >epoch=0,error=6.763
# >epoch=0,error=6.076
# >epoch=0,error=16.350
# >epoch=0,error=4.245
# >epoch=0,error=7.926
# >epoch=0,error=18.641
# >epoch=0,error=18.809
# >epoch=0,error=-0.676
# >epoch=0,error=6.440
# >epoch=0,error=5.562
# >epoch=0,error=13.384
# >epoch=0,error=11.711
# >epoch=0,error=4.343
# >epoch=0,error=7.516
# >epoch=0,error=4.314
# >epoch=0,error=4.192
# >epoch=0,error=2.079
# >epoch=0,error=5.498
# >epoch=0,error=2.115
# >epoch=0,error=15.208
# >epoch=0,error=-2.725
# >epoch=0,error=2.597
# >epoch=0,error=5.357
# >epoch=0,error=13.989
# >epoch=0,error=13.669
# >epoch=0,error=7.315
# >epoch=0,error=5.358
# >epoch=0,error=-0.258
# >epoch=0,error=17.352
# >epoch=0,error=2.768
# >epoch=0,error=11.125
# >epoch=0,error=-2.384
# >epoch=0,error=9.370
# >epoch=0,error=11.640
# >epoch=0,error=11.190
# >epoch=0,error=9.726
# >epoch=0,error=-0.719
# >epoch=0,error=2.933
# >epoch=0,error=-1.766
# >epoch=0,error=17.825
# >epoch=0,error=-3.592
# >epoch=0,error=10.584
# >epoch=0,error=10.732
# >epoch=0,error=8.392
# >epoch=0,error=19.966
# >epoch=0,error=22.056
# >epoch=0,error=5.639
# >epoch=0,error=17.973
# >epoch=0,error=12.299
# >epoch=0,error=5.862
# >epoch=0,error=4.566
# >epoch=0,error=-0.191
# >epoch=0,error=12.983
# >epoch=0,error=6.461
# >epoch=0,error=16.562
# >epoch=0,error=22.401
# >epoch=0,error=2.760
# >epoch=0,error=2.599
# >epoch=0,error=15.513
# >epoch=0,error=23.231
# >epoch=0,error=18.979
# >epoch=0,error=5.582
# >epoch=0,error=15.093
# >epoch=0,error=3.174
# >epoch=0,error=7.840
# >epoch=0,error=10.907
# >epoch=0,error=18.861
# >epoch=0,error=4.773
# >epoch=0,error=-1.247
# >epoch=0,error=0.426
# >epoch=0,error=16.783
# >epoch=0,error=12.902
# >epoch=0,error=22.788
# >epoch=0,error=20.042
# >epoch=0,error=8.394
# >epoch=0,error=19.850
# >epoch=0,error=9.349
# >epoch=0,error=2.238
# >epoch=0,error=14.125
# >epoch=0,error=5.007
# >epoch=0,error=17.407
# >epoch=0,error=5.531
# >epoch=0,error=-5.671
# >epoch=0,error=2.805
# >epoch=0,error=20.709
# >epoch=0,error=-3.690
# >epoch=0,error=6.943
# >epoch=0,error=7.341
# >epoch=0,error=3.468
# >epoch=0,error=11.939
# >epoch=0,error=11.212
# >epoch=0,error=4.265
# >epoch=0,error=9.801
# >epoch=0,error=5.284
# >epoch=0,error=12.784
# >epoch=0,error=7.922
# >epoch=0,error=18.652
# >epoch=0,error=-0.205
# >epoch=0,error=-0.827
# >epoch=0,error=8.749
# >epoch=0,error=10.655
# >epoch=0,error=21.761
# >epoch=0,error=28.204
# >epoch=0,error=9.570
# >epoch=0,error=10.993
# >epoch=0,error=10.584
# >epoch=0,error=6.836
# >epoch=0,error=10.878
# >epoch=0,error=19.951
# >epoch=0,error=8.870
# >epoch=0,error=10.367
# >epoch=0,error=16.010
# >epoch=0,error=3.652
# >epoch=0,error=-2.424
# >epoch=0,error=13.688
# >epoch=0,error=1.341
# >epoch=0,error=9.762
# >epoch=0,error=0.327
# >epoch=0,error=3.174
# >epoch=0,error=2.517
# >epoch=0,error=6.248
# >epoch=0,error=5.018
# >epoch=0,error=13.248
# >epoch=0,error=16.816
# >epoch=0,error=10.421
# >epoch=0,error=13.090
# >epoch=0,error=16.205
# >epoch=0,error=2.944
# >epoch=0,error=10.816
# >epoch=0,error=17.674
# >epoch=0,error=3.119
# >epoch=0,error=12.459
# >epoch=0,error=14.327
# >epoch=0,error=15.552
# >epoch=0,error=19.270
# >epoch=0,error=11.148
# >epoch=0,error=3.635
# >epoch=0,error=10.040
# >epoch=0,error=21.406
# >epoch=0,error=4.793
# >epoch=0,error=14.732
# >epoch=0,error=11.524
# >epoch=0,error=10.549
# >epoch=0,error=7.194
# >epoch=0,error=19.879
# >epoch=0,error=10.787
# >epoch=0,error=17.545
# >epoch=0,error=-2.816
# >epoch=0,error=10.108
# >epoch=0,error=25.997
# >epoch=0,error=9.778
# >epoch=0,error=-8.127
# >epoch=0,error=-0.075
# >epoch=0,error=15.979
# >epoch=0,error=13.681
# >epoch=0,error=7.669
# >epoch=0,error=11.619
# >epoch=0,error=13.060
# >epoch=0,error=9.141
# >epoch=0,error=1.863
# >epoch=0,error=25.013
# >epoch=0,error=15.191
# >epoch=0,error=-4.025
# >epoch=0,error=9.803
# >epoch=0,error=6.946
# >epoch=0,error=1.127
# >epoch=0,error=5.238
# >epoch=0,error=4.351
# >epoch=0,error=5.609
# >epoch=0,error=19.145
# >epoch=0,error=22.780
# >epoch=0,error=-2.647
# >epoch=0,error=21.240
# >epoch=0,error=4.950
# >epoch=0,error=23.395
# >epoch=0,error=8.267
# >epoch=0,error=3.380
# >epoch=0,error=4.882
# >epoch=0,error=19.173
# >epoch=0,error=15.832
# >epoch=0,error=16.282
# >epoch=0,error=5.778
# >epoch=0,error=18.520
# >epoch=0,error=18.833
# >epoch=0,error=4.935
# >epoch=0,error=11.534
# >epoch=0,error=2.880
# >epoch=0,error=7.547
# >epoch=0,error=14.229
# >epoch=0,error=7.454
# >epoch=0,error=15.025
# >epoch=0,error=6.045
# >epoch=0,error=6.469
# >epoch=0,error=7.351
# >epoch=0,error=14.021
# >epoch=0,error=-0.975
# >epoch=0,error=15.443
# >epoch=0,error=9.151
# >epoch=0,error=4.044
# >epoch=0,error=5.218
# >epoch=0,error=-3.615
# >epoch=0,error=13.078
# >epoch=0,error=3.291
# >epoch=0,error=9.738
# >epoch=0,error=8.664
# >epoch=0,error=26.280
# >epoch=0,error=2.082
# >epoch=0,error=6.668
# >epoch=0,error=22.395
# >epoch=0,error=14.928
# >epoch=0,error=16.641
# >epoch=0,error=7.814
# >epoch=0,error=8.855
# >epoch=0,error=15.147
# >epoch=0,error=3.081
# >epoch=0,error=12.957
# >epoch=0,error=2.117
# >epoch=0,error=8.762
# >epoch=0,error=-2.077
# >epoch=0,error=12.941
# >epoch=0,error=15.279
# >epoch=0,error=3.955
# >epoch=0,error=5.446
# >epoch=0,error=-1.643
# >epoch=0,error=-4.650
# >epoch=0,error=18.655
# >epoch=0,error=11.572
# >epoch=0,error=20.559
# >epoch=0,error=20.072
# >epoch=0,error=6.939
# >epoch=0,error=6.313
# >epoch=0,error=5.896
# >epoch=0,error=3.504
# >epoch=0,error=9.864
# >epoch=0,error=9.260
# >epoch=0,error=12.434
# >epoch=0,error=8.937
# >epoch=0,error=-0.326
# >epoch=0,error=21.299
# >epoch=0,error=26.222
# >epoch=0,error=-5.871
# >epoch=0,error=11.809
# >epoch=0,error=28.128
# >epoch=0,error=8.723
# >epoch=0,error=10.065
# >epoch=0,error=4.158
# >epoch=0,error=4.487
# >epoch=0,error=-1.510
# >epoch=0,error=10.525
# >epoch=0,error=-5.121
# >epoch=0,error=4.953
# >epoch=0,error=2.657
# >epoch=0,error=6.203
# >epoch=0,error=-0.146
# >epoch=0,error=18.794
# >epoch=0,error=5.922
# >epoch=0,error=6.648
# >epoch=0,error=4.031
# >epoch=0,error=9.846
# >epoch=0,error=3.622
# >epoch=0,error=11.331
# >epoch=0,error=0.168
# >epoch=0,error=20.066
# >epoch=0,error=26.511
# >epoch=0,error=18.750
# >epoch=0,error=14.729
# >epoch=0,error=13.319
# >epoch=0,error=5.576
# >epoch=0,error=-3.788
# >epoch=0,error=12.195
# >epoch=0,error=-0.486
# >epoch=0,error=-2.316
# >epoch=0,error=1.193
# >epoch=0,error=-2.125
# >epoch=0,error=0.898
# >epoch=0,error=-0.736
# >epoch=0,error=26.844
# >epoch=0,error=11.364
# >epoch=0,error=7.698
# >epoch=0,error=1.451
# >epoch=0,error=18.221
# >epoch=0,error=12.719
# >epoch=0,error=6.473
# >epoch=0,error=9.210
# >epoch=0,error=-0.636
# >epoch=0,error=22.513
# >epoch=0,error=9.935
# >epoch=0,error=6.290
# >epoch=0,error=9.297
# >epoch=0,error=-0.446
# >epoch=0,error=12.397
# >epoch=0,error=-5.079
# >epoch=0,error=7.002
# >epoch=0,error=9.398
# >epoch=0,error=20.546
# >epoch=0,error=-4.963
# >epoch=0,error=3.973
# >epoch=0,error=4.104
# >epoch=0,error=3.057
# >epoch=0,error=6.997
# >epoch=0,error=8.695
# >epoch=0,error=5.535
# >epoch=0,error=12.752
# >epoch=0,error=2.824
# >epoch=0,error=7.762
# >epoch=0,error=4.590
# >epoch=0,error=10.526
# >epoch=0,error=8.190
# >epoch=0,error=10.324
# >epoch=0,error=12.394
# >epoch=0,error=-1.505
# >epoch=0,error=11.197
# >epoch=0,error=0.062
# >epoch=0,error=4.209
# >epoch=0,error=18.203
# >epoch=0,error=8.455
# >epoch=0,error=0.309
# >epoch=0,error=1.997
# >epoch=0,error=0.320
# >epoch=0,error=13.290
# >epoch=0,error=-2.128
# >epoch=0,error=2.535
# >epoch=0,error=2.127
# >epoch=0,error=8.010
# >epoch=0,error=7.773
# >epoch=0,error=1.487
# >epoch=0,error=7.759
# >epoch=0,error=8.912
# >epoch=0,error=14.154
# >epoch=0,error=11.009
# >epoch=0,error=7.809
# >epoch=0,error=4.608
# >epoch=0,error=3.129
# >epoch=0,error=1.778
# >epoch=0,error=5.839
# >epoch=0,error=3.744
# >epoch=0,error=10.377
# >epoch=0,error=17.312
# >epoch=0,error=15.531
# >epoch=0,error=8.182
# >epoch=0,error=-4.263
# >epoch=0,error=9.437
# >epoch=0,error=16.502
# >epoch=0,error=30.678
# >epoch=0,error=15.811
# >epoch=0,error=1.598
# >epoch=0,error=-2.892
# >epoch=0,error=14.672
# >epoch=0,error=-2.056
# >epoch=0,error=11.167
# >epoch=0,error=5.862
# >epoch=0,error=25.120
# >epoch=0,error=14.137
# >epoch=0,error=8.166
# >epoch=0,error=14.639
# >epoch=0,error=9.447
# >epoch=0,error=1.980
# >epoch=0,error=7.756
# >epoch=0,error=6.213
# >epoch=0,error=18.161
# >epoch=0,error=13.041
# >epoch=0,error=5.739
# >epoch=0,error=6.724
# >epoch=0,error=15.178
# >epoch=0,error=24.636
# >epoch=0,error=12.301
# >epoch=0,error=16.476
# >epoch=0,error=-1.720
# >epoch=0,error=5.818
# >epoch=0,error=4.813
# >epoch=0,error=10.618
# >epoch=0,error=8.984
# >epoch=0,error=14.008
# >epoch=0,error=15.042
# >epoch=0,error=16.840
# >epoch=0,error=4.427
# >epoch=0,error=4.916
# >epoch=0,error=15.732
# >epoch=0,error=-0.720
# >epoch=0,error=13.648
# >epoch=0,error=-3.610
# >epoch=0,error=4.735
# >epoch=0,error=8.533
# >epoch=0,error=0.189
# >epoch=0,error=13.081
# >epoch=0,error=3.376
# >epoch=0,error=15.861
# >epoch=0,error=17.648
# >epoch=0,error=2.665
# >epoch=0,error=9.182
# >epoch=0,error=6.769
# >epoch=0,error=14.270
# >epoch=0,error=11.140
# >epoch=0,error=2.115
# >epoch=0,error=13.922
# >epoch=0,error=10.920
# >epoch=0,error=6.105
# >epoch=0,error=8.250
# >epoch=0,error=-0.956
# >epoch=0,error=1.557
# >epoch=0,error=1.566
# >epoch=0,error=15.147
# >epoch=0,error=2.303
# >epoch=0,error=12.759
# >epoch=0,error=13.181
# >epoch=0,error=5.963
# >epoch=0,error=15.126
# >epoch=0,error=10.520
# >epoch=0,error=7.692
# >epoch=0,error=26.848
# >epoch=0,error=16.391
# >epoch=0,error=14.421
# >epoch=0,error=2.064
# >epoch=0,error=16.109
# >epoch=0,error=8.073
# >epoch=0,error=4.255
# >epoch=0,error=7.576
# >epoch=0,error=8.664
# >epoch=0,error=-2.084
# >epoch=0,error=23.410
# >epoch=0,error=9.641
# >epoch=0,error=-0.717
# >epoch=0,error=24.615
# >epoch=0,error=12.630
# >epoch=0,error=-4.727
# >epoch=0,error=-2.303
# >epoch=0,error=3.188
# >epoch=0,error=-2.040
# >epoch=0,error=16.211
# >epoch=0,error=16.998
# >epoch=0,error=10.572
# >epoch=0,error=18.641
# >epoch=0,error=8.790
# >epoch=0,error=16.324
# >epoch=0,error=17.642
# >epoch=0,error=15.360
# >epoch=0,error=1.658
# >epoch=0,error=11.685
# >epoch=0,error=25.214
# >epoch=0,error=1.826
# >epoch=0,error=15.801
# >epoch=0,error=2.628
# >epoch=0,error=18.961
# >epoch=0,error=5.550
# >epoch=0,error=4.422
# >epoch=0,error=14.715
# >epoch=0,error=20.818
# >epoch=0,error=11.948
# >epoch=0,error=0.495
# >epoch=0,error=21.106
# >epoch=0,error=9.688
# >epoch=0,error=8.965
# >epoch=0,error=-3.108
# >epoch=0,error=3.355
# >epoch=0,error=14.261
# >epoch=0,error=23.757
# >epoch=0,error=6.441
# >epoch=0,error=9.522
# >epoch=0,error=9.575
# >epoch=0,error=6.972
# >epoch=0,error=14.434
# >epoch=0,error=10.668
# >epoch=0,error=11.946
# >epoch=0,error=-2.268
# >epoch=0,error=16.945
# >epoch=0,error=8.219
# >epoch=0,error=22.656
# >epoch=0,error=6.252
# >epoch=0,error=2.278
# >epoch=0,error=3.109
# >epoch=0,error=6.222
# >epoch=0,error=18.961
# >epoch=0,error=25.708
# >epoch=0,error=18.829
# >epoch=0,error=8.619
# >epoch=0,error=19.346
# >epoch=0,error=7.292
# >epoch=0,error=5.703
# >epoch=0,error=10.945
# >epoch=0,error=-1.220
# >epoch=0,error=4.096
# >epoch=0,error=10.080
# >epoch=0,error=6.790
# >epoch=0,error=-4.248
# >epoch=0,error=12.579
# >epoch=0,error=21.392
# >epoch=0,error=3.663
# >epoch=0,error=13.158
# >epoch=0,error=-0.694
# >epoch=0,error=13.637
# >epoch=0,error=9.607
# >epoch=0,error=2.123
# >epoch=0,error=7.417
# >epoch=0,error=15.337
# >epoch=0,error=-1.824
# >epoch=0,error=-7.346
# >epoch=0,error=4.255
# >epoch=0,error=3.741
# >epoch=0,error=12.021
# >epoch=0,error=10.155
# >epoch=0,error=9.855
# >epoch=0,error=17.669
# >epoch=0,error=14.381
# >epoch=0,error=4.517
# >epoch=0,error=15.639
# >epoch=0,error=17.540
# >epoch=0,error=5.294
# >epoch=0,error=0.553
# >epoch=0,error=-3.247
# >epoch=0,error=5.135
# >epoch=0,error=4.440
# >epoch=0,error=10.443
# >epoch=0,error=-1.768
# >epoch=0,error=4.735
# >epoch=0,error=7.354
# >epoch=0,error=1.676
# >epoch=0,error=14.530
# >epoch=0,error=13.644
# >epoch=0,error=14.516
# >epoch=0,error=22.184
# >epoch=0,error=7.777
# >epoch=0,error=10.851
# >epoch=0,error=7.545
# >epoch=0,error=11.334
# >epoch=0,error=23.074
# >epoch=0,error=24.003
# >epoch=0,error=5.086
# >epoch=0,error=6.300
# >epoch=0,error=5.866
# >epoch=0,error=0.658
# >epoch=0,error=2.126
# >epoch=0,error=-2.061
# >epoch=0,error=-1.556
# >epoch=0,error=-0.812
# >epoch=0,error=16.360
# >epoch=0,error=12.739
# >epoch=0,error=8.051
# >epoch=0,error=13.075
# >epoch=0,error=3.501
# >epoch=0,error=9.292
# >epoch=0,error=4.949
# >epoch=0,error=6.576
# >epoch=0,error=8.013
# >epoch=0,error=20.485
# >epoch=0,error=16.160
# >epoch=0,error=3.662
# >epoch=0,error=18.178
# >epoch=0,error=8.866
# >epoch=0,error=7.094
# >epoch=0,error=19.207
# >epoch=0,error=0.777
# >epoch=0,error=17.808
# >epoch=0,error=12.572
# >epoch=0,error=13.270
# >epoch=0,error=11.534
# >epoch=0,error=15.534
# >epoch=0,error=14.665
# >epoch=0,error=3.602
# >epoch=0,error=16.897
# >epoch=0,error=15.764
# >epoch=0,error=4.131
# >epoch=0,error=3.408
# >epoch=0,error=8.219
# >epoch=0,error=0.195
# >epoch=0,error=16.735
# >epoch=0,error=14.451
# >epoch=0,error=17.561
# >epoch=0,error=21.334
# >epoch=0,error=6.720
# >epoch=0,error=18.554
# >epoch=0,error=11.507
# >epoch=0,error=21.374
# >epoch=0,error=10.029
# >epoch=0,error=8.109
# >epoch=0,error=-2.287
# >epoch=0,error=15.541
# >epoch=0,error=9.759
# >epoch=0,error=22.633
# >epoch=0,error=5.324
# >epoch=0,error=-1.258
# >epoch=0,error=3.247
# >epoch=0,error=4.260
# >epoch=0,error=22.017
# >epoch=0,error=15.031
# >epoch=0,error=10.981
# >epoch=0,error=-1.311
# >epoch=0,error=10.023
# >epoch=0,error=7.825
# >epoch=0,error=0.368
# >epoch=0,error=8.043
# >epoch=0,error=16.302
# >epoch=0,error=20.802
# >epoch=0,error=0.795
# >epoch=0,error=20.183
# >epoch=0,error=18.892
# >epoch=0,error=13.613
# >epoch=0,error=4.772
# >epoch=0,error=11.577
# >epoch=0,error=14.028
# >epoch=0,error=8.723
# >epoch=0,error=12.021
# >epoch=0,error=12.217
# >epoch=0,error=20.508
# >epoch=0,error=18.969
# >epoch=0,error=6.537
# >epoch=0,error=16.675
# >epoch=0,error=13.495
# >epoch=0,error=11.634
# >epoch=0,error=13.056
# >epoch=0,error=6.484
# >epoch=0,error=3.510
# >epoch=0,error=0.977
# >epoch=0,error=8.460
# >epoch=0,error=8.997
# >epoch=0,error=15.786
# >epoch=0,error=-4.078
# >epoch=0,error=10.580
# >epoch=0,error=5.083
# >epoch=0,error=3.599
# >epoch=0,error=12.096
# >epoch=0,error=15.363
# >epoch=0,error=13.990
# >epoch=0,error=14.311
# >epoch=0,error=4.531
# >epoch=0,error=11.640
# >epoch=0,error=7.489
# >epoch=0,error=12.303
# >epoch=0,error=4.730
# >epoch=0,error=7.089
# >epoch=0,error=13.057
# >epoch=0,error=12.355
# >epoch=0,error=5.849
# >epoch=0,error=13.853
# >epoch=0,error=6.946
# >epoch=0,error=1.659
# >epoch=0,error=0.456
# >epoch=0,error=11.087
# >epoch=0,error=22.814
# >epoch=0,error=25.880
# >epoch=0,error=17.490
# >epoch=0,error=15.083
# >epoch=0,error=7.028
# >epoch=0,error=31.371
# >epoch=0,error=10.720
# >epoch=0,error=8.266
# >epoch=0,error=2.776
# >epoch=0,error=-5.964
# >epoch=0,error=-1.324
# >epoch=0,error=-0.503
# >epoch=0,error=7.375
# >epoch=0,error=17.511
# >epoch=0,error=17.171
# >epoch=0,error=25.233
# >epoch=0,error=18.854
# >epoch=0,error=23.817
# >epoch=0,error=0.439
# >epoch=0,error=4.814
# >epoch=0,error=5.208
# >epoch=0,error=0.576
# >epoch=0,error=21.792
# >epoch=0,error=-0.022
# >epoch=0,error=6.376
# >epoch=0,error=4.955
# >epoch=0,error=12.513
# >epoch=0,error=-0.569
# >epoch=0,error=5.110
# >epoch=0,error=4.538
# >epoch=0,error=19.012
# >epoch=0,error=4.100
# >epoch=0,error=9.898
# >epoch=0,error=11.962
# >epoch=0,error=4.751
# >epoch=0,error=10.974
# >epoch=0,error=22.015
# >epoch=0,error=12.504
# >epoch=0,error=12.180
# >epoch=0,error=7.065
# >epoch=0,error=17.988
# >epoch=0,error=1.144
# >epoch=0,error=12.879
# >epoch=0,error=6.116
# >epoch=0,error=3.490
# >epoch=0,error=25.939
# >epoch=0,error=9.982
# >epoch=0,error=8.794
# >epoch=0,error=1.749
# >epoch=0,error=3.709
# >epoch=0,error=9.898
# >epoch=0,error=14.676
# >epoch=0,error=16.466
# >epoch=0,error=5.658
# >epoch=0,error=1.665
# >epoch=0,error=4.320
# >epoch=0,error=13.042
# >epoch=0,error=0.522
# >epoch=0,error=17.157
# >epoch=0,error=21.734
# >epoch=0,error=22.226
# >epoch=0,error=6.165
# >epoch=0,error=-0.853
# >epoch=0,error=6.987
# >epoch=0,error=5.919
# >epoch=0,error=6.133
# >epoch=0,error=-2.706
# >epoch=0,error=13.691
# >epoch=0,error=9.633
# >epoch=0,error=11.913
# >epoch=0,error=24.921
# >epoch=0,error=17.196
# >epoch=0,error=7.440
# >epoch=0,error=19.933
# >epoch=0,error=10.094
# >epoch=0,error=9.211
# >epoch=0,error=2.235
# >epoch=0,error=3.091
# >epoch=0,error=13.891
# >epoch=0,error=13.984
# >epoch=0,error=16.606
# >epoch=0,error=11.832
# >epoch=0,error=1.313
# >epoch=0,error=12.418
# >epoch=0,error=-2.870
# >epoch=0,error=7.047
# >epoch=0,error=13.595
# >epoch=0,error=23.212
# >epoch=0,error=4.387
# >epoch=0,error=6.936
# >epoch=0,error=-2.289
# >epoch=0,error=7.325
# >epoch=0,error=6.394
# >epoch=0,error=14.782
# >epoch=0,error=6.030
# >epoch=0,error=0.556
# >epoch=0,error=10.517
# >epoch=0,error=12.911
# >epoch=0,error=9.789
# >epoch=0,error=8.968
# >epoch=0,error=10.256
# >epoch=0,error=15.061
# >epoch=0,error=15.067
# >epoch=0,error=6.002
# >epoch=0,error=22.893
# >epoch=0,error=5.684
# >epoch=0,error=3.255
# >epoch=0,error=12.422
# >epoch=0,error=9.168
# >epoch=0,error=6.450
# >epoch=0,error=10.830
# >epoch=0,error=4.581
# >epoch=0,error=8.806
# >epoch=0,error=7.286
# >epoch=0,error=19.239
# >epoch=0,error=9.855
# >epoch=0,error=10.090
# >epoch=0,error=14.801
# >epoch=0,error=12.775
# >epoch=0,error=6.346
# >epoch=0,error=-5.488
# >epoch=0,error=4.966
# >epoch=0,error=11.287
# >epoch=0,error=17.200
# >epoch=0,error=-0.751
# >epoch=0,error=13.528
# >epoch=0,error=6.487
# >epoch=0,error=14.465
# >epoch=0,error=9.717
# >epoch=0,error=-1.137
# >epoch=0,error=7.227
# >epoch=0,error=0.130
# >epoch=0,error=13.011
# >epoch=0,error=2.063
# >epoch=0,error=9.240
# >epoch=0,error=22.380
# >epoch=0,error=5.485
# >epoch=0,error=11.222
# >epoch=0,error=4.540
# >epoch=0,error=20.347
# >epoch=0,error=-2.169
# >epoch=0,error=10.008
# >epoch=0,error=18.131
# >epoch=0,error=13.264
# >epoch=0,error=9.650
# >epoch=0,error=7.022
# >epoch=0,error=7.302
# >epoch=0,error=-2.737
# >epoch=0,error=21.053
# >epoch=0,error=14.906
# >epoch=0,error=2.524
# >epoch=0,error=2.330
# >epoch=0,error=3.055
# >epoch=0,error=17.503
# >epoch=0,error=13.859
# >epoch=0,error=1.212
# >epoch=0,error=15.072
# >epoch=0,error=12.447
# >epoch=0,error=3.464
# >epoch=0,error=13.616
# >epoch=0,error=5.192
# >epoch=0,error=17.870
# >epoch=0,error=9.892
# >epoch=0,error=9.895
# >epoch=0,error=5.477
# >epoch=0,error=-3.550
# >epoch=0,error=15.804
# >epoch=0,error=4.717
# >epoch=0,error=5.487
# >epoch=0,error=8.990
# >epoch=0,error=2.036
# >epoch=0,error=-1.184
# >epoch=0,error=3.198
# >epoch=0,error=12.947
# >epoch=0,error=21.265
# >epoch=0,error=3.449
# >epoch=0,error=15.203
# >epoch=0,error=6.141
# >epoch=0,error=3.948
# >epoch=0,error=5.590
# >epoch=0,error=10.738
# >epoch=0,error=-0.732
# >epoch=0,error=14.136
# >epoch=0,error=6.152
# >epoch=0,error=22.860
# >epoch=0,error=13.434
# >epoch=0,error=23.286
# >epoch=0,error=23.181
# >epoch=0,error=15.830
# >epoch=0,error=11.794
# >epoch=0,error=4.104
# >epoch=0,error=10.296
# >epoch=0,error=3.800
# >epoch=0,error=14.850
# >epoch=0,error=14.874
# >epoch=0,error=15.336
# >epoch=0,error=2.118
# >epoch=0,error=24.557
# >epoch=0,error=11.535
# >epoch=0,error=-4.269
# >epoch=0,error=18.127
# >epoch=0,error=25.905
# >epoch=0,error=19.573
# >epoch=0,error=11.452
# >epoch=0,error=10.157
# >epoch=0,error=15.052
# >epoch=0,error=2.744
# >epoch=0,error=6.898
# >epoch=0,error=2.732
# >epoch=0,error=0.439
# >epoch=0,error=14.976
# >epoch=0,error=18.300
# >epoch=0,error=-0.368
# >epoch=0,error=4.946
# >epoch=0,error=7.598
# >epoch=0,error=28.213
# >epoch=0,error=2.591
# >epoch=0,error=10.678
# >epoch=0,error=4.343
# >epoch=0,error=17.080
# >epoch=0,error=-1.847
# >epoch=0,error=5.290
# >epoch=0,error=12.033
# >epoch=0,error=11.912
# >epoch=0,error=4.449
# >epoch=0,error=4.079
# >epoch=0,error=-0.747
# >epoch=0,error=20.966
# >epoch=0,error=9.718
# >epoch=0,error=2.686
# >epoch=0,error=19.647
# >epoch=0,error=3.066
# >epoch=0,error=12.882
# >epoch=0,error=22.928
# >epoch=0,error=14.212
# >epoch=0,error=19.465
# >epoch=0,error=26.909
# >epoch=0,error=3.825
# >epoch=0,error=6.683
# >epoch=0,error=11.792
# >epoch=0,error=5.470
# >epoch=0,error=13.435
# >epoch=0,error=-0.510
# >epoch=0,error=0.702
# >epoch=0,error=11.941
# >epoch=0,error=11.656
# >epoch=0,error=8.260
# >epoch=0,error=1.894
# >epoch=0,error=13.251
# >epoch=0,error=-1.822
# >epoch=0,error=0.354
# >epoch=0,error=2.528
# >epoch=0,error=5.762
# >epoch=1,error=13.458
# >epoch=1,error=18.319
# >epoch=1,error=6.847
# >epoch=1,error=4.990
# >epoch=1,error=13.107
# >epoch=1,error=6.889
# >epoch=1,error=6.183
# >epoch=1,error=10.106
# >epoch=1,error=13.474
# >epoch=1,error=23.008
# >epoch=1,error=8.825
# >epoch=1,error=4.649
# >epoch=1,error=16.157
# >epoch=1,error=15.381
# >epoch=1,error=21.336
# >epoch=1,error=8.065
# >epoch=1,error=9.496
# >epoch=1,error=5.467
# >epoch=1,error=14.086
# >epoch=1,error=6.118
# >epoch=1,error=17.279
# >epoch=1,error=9.110
# >epoch=1,error=20.093
# >epoch=1,error=7.672
# >epoch=1,error=9.206
# >epoch=1,error=-2.551
# >epoch=1,error=10.304
# >epoch=1,error=25.079
# >epoch=1,error=3.909
# >epoch=1,error=9.577
# >epoch=1,error=8.904
# >epoch=1,error=20.917
# >epoch=1,error=-0.084
# >epoch=1,error=6.389
# >epoch=1,error=4.873
# >epoch=1,error=7.709
# >epoch=1,error=9.956
# >epoch=1,error=18.340
# >epoch=1,error=6.927
# >epoch=1,error=10.806
# >epoch=1,error=11.172
# >epoch=1,error=7.412
# >epoch=1,error=12.750
# >epoch=1,error=15.205
# >epoch=1,error=9.551
# >epoch=1,error=13.697
# >epoch=1,error=7.843
# >epoch=1,error=0.064
# >epoch=1,error=13.647
# >epoch=1,error=3.989
# >epoch=1,error=3.620
# >epoch=1,error=15.083
# >epoch=1,error=0.675
# >epoch=1,error=8.021
# >epoch=1,error=-0.122
# >epoch=1,error=4.877
# >epoch=1,error=13.648
# >epoch=1,error=17.263
# >epoch=1,error=25.561
# >epoch=1,error=8.632
# >epoch=1,error=19.321
# >epoch=1,error=9.748
# >epoch=1,error=13.856
# >epoch=1,error=4.914
# >epoch=1,error=16.987
# >epoch=1,error=19.555
# >epoch=1,error=4.320
# >epoch=1,error=2.342
# >epoch=1,error=17.198
# >epoch=1,error=5.388
# >epoch=1,error=15.436
# >epoch=1,error=6.963
# >epoch=1,error=11.543
# >epoch=1,error=16.034
# >epoch=1,error=1.853
# >epoch=1,error=6.627
# >epoch=1,error=-6.665
# >epoch=1,error=15.791
# >epoch=1,error=2.390
# >epoch=1,error=16.080
# >epoch=1,error=-1.012
# >epoch=1,error=6.411
# >epoch=1,error=-1.734
# >epoch=1,error=10.227
# >epoch=1,error=8.939
# >epoch=1,error=22.409
# >epoch=1,error=8.163
# >epoch=1,error=6.592
# >epoch=1,error=11.784
# >epoch=1,error=12.167
# >epoch=1,error=0.183
# >epoch=1,error=29.079
# >epoch=1,error=6.518
# >epoch=1,error=17.320
# >epoch=1,error=14.394
# >epoch=1,error=1.539
# >epoch=1,error=0.614
# >epoch=1,error=0.468
# >epoch=1,error=24.829
# >epoch=1,error=8.919
# >epoch=1,error=7.697
# >epoch=1,error=1.143
# >epoch=1,error=13.807
# >epoch=1,error=22.685
# >epoch=1,error=16.195
# >epoch=1,error=0.080
# >epoch=1,error=6.602
# >epoch=1,error=22.170
# >epoch=1,error=20.138
# >epoch=1,error=7.815
# >epoch=1,error=6.600
# >epoch=1,error=6.135
# >epoch=1,error=16.350
# >epoch=1,error=4.245
# >epoch=1,error=7.926
# >epoch=1,error=18.641
# >epoch=1,error=18.809
# >epoch=1,error=-0.676
# >epoch=1,error=6.440
# >epoch=1,error=5.562
# >epoch=1,error=13.384
# >epoch=1,error=11.711
# >epoch=1,error=4.343
# >epoch=1,error=7.516
# >epoch=1,error=4.314
# >epoch=1,error=4.192
# >epoch=1,error=2.079
# >epoch=1,error=5.498
# >epoch=1,error=2.115
# >epoch=1,error=15.208
# >epoch=1,error=-2.724
# >epoch=1,error=2.600
# >epoch=1,error=5.341
# >epoch=1,error=13.990
# >epoch=1,error=13.669
# >epoch=1,error=7.315
# >epoch=1,error=5.358
# >epoch=1,error=-0.258
# >epoch=1,error=17.352
# >epoch=1,error=2.768
# >epoch=1,error=11.125
# >epoch=1,error=-2.384
# >epoch=1,error=8.940
# >epoch=1,error=11.640
# >epoch=1,error=11.190
# >epoch=1,error=9.726
# >epoch=1,error=-0.719
# >epoch=1,error=2.933
# >epoch=1,error=-1.766
# >epoch=1,error=17.825
# >epoch=1,error=-3.592
# >epoch=1,error=10.584
# >epoch=1,error=10.732
# >epoch=1,error=8.392
# >epoch=1,error=19.966
# >epoch=1,error=22.056
# >epoch=1,error=5.639
# >epoch=1,error=17.973
# >epoch=1,error=12.299
# >epoch=1,error=5.861
# >epoch=1,error=4.566
# >epoch=1,error=-0.191
# >epoch=1,error=12.983
# >epoch=1,error=6.461
# >epoch=1,error=16.562
# >epoch=1,error=22.401
# >epoch=1,error=2.760
# >epoch=1,error=2.599
# >epoch=1,error=15.513
# >epoch=1,error=23.231
# >epoch=1,error=18.979
# >epoch=1,error=5.582
# >epoch=1,error=15.093
# >epoch=1,error=2.227
# >epoch=1,error=7.840
# >epoch=1,error=10.907
# >epoch=1,error=18.861
# >epoch=1,error=4.796
# >epoch=1,error=-1.247
# >epoch=1,error=0.426
# >epoch=1,error=16.783
# >epoch=1,error=12.902
# >epoch=1,error=22.788
# >epoch=1,error=20.042
# >epoch=1,error=8.394
# >epoch=1,error=19.850
# >epoch=1,error=9.349
# >epoch=1,error=2.237
# >epoch=1,error=14.125
# >epoch=1,error=4.464
# >epoch=1,error=17.407
# >epoch=1,error=5.531
# >epoch=1,error=-5.671
# >epoch=1,error=2.805
# >epoch=1,error=20.709
# >epoch=1,error=-3.690
# >epoch=1,error=6.943
# >epoch=1,error=7.341
# >epoch=1,error=3.468
# >epoch=1,error=11.939
# >epoch=1,error=11.212
# >epoch=1,error=4.265
# >epoch=1,error=9.801
# >epoch=1,error=5.284
# >epoch=1,error=12.784
# >epoch=1,error=7.922
# >epoch=1,error=18.652
# >epoch=1,error=-0.205
# >epoch=1,error=-0.582
# >epoch=1,error=8.749
# >epoch=1,error=10.655
# >epoch=1,error=21.761
# >epoch=1,error=28.204
# >epoch=1,error=9.570
# >epoch=1,error=10.993
# >epoch=1,error=10.584
# >epoch=1,error=6.836
# >epoch=1,error=10.878
# >epoch=1,error=19.951
# >epoch=1,error=8.873
# >epoch=1,error=10.365
# >epoch=1,error=16.010
# >epoch=1,error=3.652
# >epoch=1,error=-2.424
# >epoch=1,error=13.688
# >epoch=1,error=1.341
# >epoch=1,error=9.762
# >epoch=1,error=0.327
# >epoch=1,error=3.174
# >epoch=1,error=2.517
# >epoch=1,error=6.248
# >epoch=1,error=5.017
# >epoch=1,error=13.248
# >epoch=1,error=16.816
# >epoch=1,error=10.421
# >epoch=1,error=13.094
# >epoch=1,error=16.205
# >epoch=1,error=2.754
# >epoch=1,error=10.816
# >epoch=1,error=17.674
# >epoch=1,error=3.119
# >epoch=1,error=12.459
# >epoch=1,error=14.327
# >epoch=1,error=15.552
# >epoch=1,error=19.270
# >epoch=1,error=11.148
# >epoch=1,error=3.635
# >epoch=1,error=10.040
# >epoch=1,error=21.406
# >epoch=1,error=4.793
# >epoch=1,error=14.732
# >epoch=1,error=11.524
# >epoch=1,error=10.549
# >epoch=1,error=7.210
# >epoch=1,error=19.879
# >epoch=1,error=10.787
# >epoch=1,error=17.545
# >epoch=1,error=-2.816
# >epoch=1,error=10.108
# >epoch=1,error=25.997
# >epoch=1,error=9.778
# >epoch=1,error=-8.127
# >epoch=1,error=-0.075
# >epoch=1,error=15.979
# >epoch=1,error=13.681
# >epoch=1,error=7.669
# >epoch=1,error=11.619
# >epoch=1,error=13.060
# >epoch=1,error=9.141
# >epoch=1,error=1.863
# >epoch=1,error=25.013
# >epoch=1,error=15.191
# >epoch=1,error=-4.025
# >epoch=1,error=9.803
# >epoch=1,error=6.946
# >epoch=1,error=1.127
# >epoch=1,error=5.238
# >epoch=1,error=6.046
# >epoch=1,error=5.683
# >epoch=1,error=19.145
# >epoch=1,error=22.780
# >epoch=1,error=-2.647
# >epoch=1,error=21.240
# >epoch=1,error=4.950
# >epoch=1,error=23.395
# >epoch=1,error=8.267
# >epoch=1,error=3.380
# >epoch=1,error=4.882
# >epoch=1,error=19.175
# >epoch=1,error=15.832
# >epoch=1,error=16.282
# >epoch=1,error=5.778
# >epoch=1,error=18.520
# >epoch=1,error=18.833
# >epoch=1,error=4.935
# >epoch=1,error=11.534
# >epoch=1,error=2.880
# >epoch=1,error=7.547
# >epoch=1,error=14.229
# >epoch=1,error=7.441
# >epoch=1,error=15.025
# >epoch=1,error=6.045
# >epoch=1,error=6.469
# >epoch=1,error=7.320
# >epoch=1,error=14.021
# >epoch=1,error=-0.975
# >epoch=1,error=15.443
# >epoch=1,error=9.151
# >epoch=1,error=4.044
# >epoch=1,error=5.218
# >epoch=1,error=-3.615
# >epoch=1,error=13.078
# >epoch=1,error=3.291
# >epoch=1,error=9.738
# >epoch=1,error=8.664
# >epoch=1,error=26.280
# >epoch=1,error=2.087
# >epoch=1,error=6.668
# >epoch=1,error=22.395
# >epoch=1,error=14.928
# >epoch=1,error=16.641
# >epoch=1,error=7.814
# >epoch=1,error=8.856
# >epoch=1,error=15.147
# >epoch=1,error=3.081
# >epoch=1,error=13.064
# >epoch=1,error=2.117
# >epoch=1,error=8.762
# >epoch=1,error=-2.077
# >epoch=1,error=12.941
# >epoch=1,error=15.279
# >epoch=1,error=3.955
# >epoch=1,error=5.446
# >epoch=1,error=-1.643
# >epoch=1,error=-4.650
# >epoch=1,error=18.655
# >epoch=1,error=11.572
# >epoch=1,error=20.559
# >epoch=1,error=20.072
# >epoch=1,error=6.939
# >epoch=1,error=6.312
# >epoch=1,error=5.896
# >epoch=1,error=3.504
# >epoch=1,error=9.864
# >epoch=1,error=9.260
# >epoch=1,error=12.434
# >epoch=1,error=8.937
# >epoch=1,error=-0.326
# >epoch=1,error=21.299
# >epoch=1,error=26.222
# >epoch=1,error=-5.871
# >epoch=1,error=11.809
# >epoch=1,error=28.128
# >epoch=1,error=8.723
# >epoch=1,error=10.065
# >epoch=1,error=4.158
# >epoch=1,error=4.501
# >epoch=1,error=-1.510
# >epoch=1,error=10.525
# >epoch=1,error=-5.121
# >epoch=1,error=4.953
# >epoch=1,error=2.657
# >epoch=1,error=6.203
# >epoch=1,error=-0.146
# >epoch=1,error=18.794
# >epoch=1,error=5.922
# >epoch=1,error=6.648
# >epoch=1,error=4.031
# >epoch=1,error=10.009
# >epoch=1,error=3.622
# >epoch=1,error=11.331
# >epoch=1,error=0.168
# >epoch=1,error=20.066
# >epoch=1,error=26.511
# >epoch=1,error=18.750
# >epoch=1,error=14.729
# >epoch=1,error=13.319
# >epoch=1,error=5.576
# >epoch=1,error=-3.788
# >epoch=1,error=12.195
# >epoch=1,error=-0.462
# >epoch=1,error=-2.316
# >epoch=1,error=1.152
# >epoch=1,error=-2.114
# >epoch=1,error=0.898
# >epoch=1,error=-0.736
# >epoch=1,error=26.844
# >epoch=1,error=11.364
# >epoch=1,error=7.698
# >epoch=1,error=1.451
# >epoch=1,error=18.221
# >epoch=1,error=12.719
# >epoch=1,error=6.473
# >epoch=1,error=9.210
# >epoch=1,error=-0.636
# >epoch=1,error=22.513
# >epoch=1,error=9.935
# >epoch=1,error=5.159
# >epoch=1,error=9.297
# >epoch=1,error=-0.453
# >epoch=1,error=12.397
# >epoch=1,error=-5.079
# >epoch=1,error=7.002
# >epoch=1,error=9.398
# >epoch=1,error=20.546
# >epoch=1,error=-4.963
# >epoch=1,error=3.973
# >epoch=1,error=4.104
# >epoch=1,error=3.057
# >epoch=1,error=6.997
# >epoch=1,error=8.695
# >epoch=1,error=5.533
# >epoch=1,error=12.752
# >epoch=1,error=2.824
# >epoch=1,error=7.762
# >epoch=1,error=4.590
# >epoch=1,error=10.526
# >epoch=1,error=8.190
# >epoch=1,error=10.324
# >epoch=1,error=12.394
# >epoch=1,error=-1.505
# >epoch=1,error=11.197
# >epoch=1,error=0.062
# >epoch=1,error=4.209
# >epoch=1,error=18.203
# >epoch=1,error=8.455
# >epoch=1,error=0.309
# >epoch=1,error=1.997
# >epoch=1,error=0.320
# >epoch=1,error=13.290
# >epoch=1,error=-2.128
# >epoch=1,error=2.602
# >epoch=1,error=2.127
# >epoch=1,error=8.010
# >epoch=1,error=7.773
# >epoch=1,error=1.451
# >epoch=1,error=7.759
# >epoch=1,error=8.912
# >epoch=1,error=14.154
# >epoch=1,error=11.009
# >epoch=1,error=7.809
# >epoch=1,error=4.608
# >epoch=1,error=3.129
# >epoch=1,error=1.778
# >epoch=1,error=5.839
# >epoch=1,error=3.744
# >epoch=1,error=10.377
# >epoch=1,error=17.311
# >epoch=1,error=15.531
# >epoch=1,error=8.182
# >epoch=1,error=-4.263
# >epoch=1,error=9.437
# >epoch=1,error=16.502
# >epoch=1,error=30.678
# >epoch=1,error=15.811
# >epoch=1,error=1.597
# >epoch=1,error=-2.892
# >epoch=1,error=14.672
# >epoch=1,error=-1.890
# >epoch=1,error=11.167
# >epoch=1,error=5.862
# >epoch=1,error=25.120
# >epoch=1,error=14.137
# >epoch=1,error=8.166
# >epoch=1,error=14.639
# >epoch=1,error=9.447
# >epoch=1,error=1.980
# >epoch=1,error=7.756
# >epoch=1,error=6.213
# >epoch=1,error=18.161
# >epoch=1,error=13.041
# >epoch=1,error=5.739
# >epoch=1,error=6.724
# >epoch=1,error=15.178
# >epoch=1,error=24.636
# >epoch=1,error=12.301
# >epoch=1,error=16.476
# >epoch=1,error=-1.720
# >epoch=1,error=5.818
# >epoch=1,error=4.813
# >epoch=1,error=10.618
# >epoch=1,error=8.925
# >epoch=1,error=14.008
# >epoch=1,error=15.042
# >epoch=1,error=16.840
# >epoch=1,error=4.427
# >epoch=1,error=4.916
# >epoch=1,error=15.732
# >epoch=1,error=-0.720
# >epoch=1,error=13.648
# >epoch=1,error=-3.610
# >epoch=1,error=4.735
# >epoch=1,error=8.533
# >epoch=1,error=0.158
# >epoch=1,error=13.081
# >epoch=1,error=3.376
# >epoch=1,error=15.861
# >epoch=1,error=17.648
# >epoch=1,error=2.665
# >epoch=1,error=9.182
# >epoch=1,error=6.769
# >epoch=1,error=14.270
# >epoch=1,error=11.140
# >epoch=1,error=2.115
# >epoch=1,error=13.922
# >epoch=1,error=10.920
# >epoch=1,error=6.105
# >epoch=1,error=8.250
# >epoch=1,error=-0.956
# >epoch=1,error=1.557
# >epoch=1,error=1.566
# >epoch=1,error=15.147
# >epoch=1,error=2.334
# >epoch=1,error=12.759
# >epoch=1,error=13.441
# >epoch=1,error=5.963
# >epoch=1,error=15.126
# >epoch=1,error=10.520
# >epoch=1,error=8.113
# >epoch=1,error=26.848
# >epoch=1,error=16.391
# >epoch=1,error=14.421
# >epoch=1,error=2.064
# >epoch=1,error=16.109
# >epoch=1,error=8.077
# >epoch=1,error=4.255
# >epoch=1,error=7.576
# >epoch=1,error=8.489
# >epoch=1,error=-2.052
# >epoch=1,error=23.410
# >epoch=1,error=9.641
# >epoch=1,error=-0.717
# >epoch=1,error=24.615
# >epoch=1,error=12.629
# >epoch=1,error=-4.727
# >epoch=1,error=-2.303
# >epoch=1,error=3.188
# >epoch=1,error=-2.040
# >epoch=1,error=16.211
# >epoch=1,error=16.998
# >epoch=1,error=10.572
# >epoch=1,error=18.641
# >epoch=1,error=8.790
# >epoch=1,error=16.324
# >epoch=1,error=17.642
# >epoch=1,error=15.360
# >epoch=1,error=1.658
# >epoch=1,error=11.685
# >epoch=1,error=25.214
# >epoch=1,error=1.826
# >epoch=1,error=15.804
# >epoch=1,error=2.628
# >epoch=1,error=18.961
# >epoch=1,error=5.561
# >epoch=1,error=4.422
# >epoch=1,error=14.715
# >epoch=1,error=20.818
# >epoch=1,error=11.948
# >epoch=1,error=0.495
# >epoch=1,error=21.106
# >epoch=1,error=9.688
# >epoch=1,error=8.965
# >epoch=1,error=-3.108
# >epoch=1,error=3.355
# >epoch=1,error=14.261
# >epoch=1,error=23.757
# >epoch=1,error=6.444
# >epoch=1,error=9.491
# >epoch=1,error=9.583
# >epoch=1,error=6.972
# >epoch=1,error=14.434
# >epoch=1,error=10.668
# >epoch=1,error=11.946
# >epoch=1,error=-2.268
# >epoch=1,error=16.945
# >epoch=1,error=8.219
# >epoch=1,error=22.656
# >epoch=1,error=7.442
# >epoch=1,error=2.278
# >epoch=1,error=3.109
# >epoch=1,error=6.222
# >epoch=1,error=18.961
# >epoch=1,error=25.708
# >epoch=1,error=18.829
# >epoch=1,error=8.619
# >epoch=1,error=19.346
# >epoch=1,error=7.292
# >epoch=1,error=5.703
# >epoch=1,error=10.945
# >epoch=1,error=-1.220
# >epoch=1,error=4.096
# >epoch=1,error=10.080
# >epoch=1,error=6.790
# >epoch=1,error=-4.248
# >epoch=1,error=12.579
# >epoch=1,error=21.392
# >epoch=1,error=3.663
# >epoch=1,error=13.158
# >epoch=1,error=-0.694
# >epoch=1,error=13.637
# >epoch=1,error=9.607
# >epoch=1,error=2.123
# >epoch=1,error=7.417
# >epoch=1,error=15.337
# >epoch=1,error=-1.948
# >epoch=1,error=-7.346
# >epoch=1,error=4.254
# >epoch=1,error=3.741
# >epoch=1,error=12.021
# >epoch=1,error=10.155
# >epoch=1,error=9.855
# >epoch=1,error=17.669
# >epoch=1,error=14.381
# >epoch=1,error=4.517
# >epoch=1,error=15.639
# >epoch=1,error=17.540
# >epoch=1,error=5.309
# >epoch=1,error=0.184
# >epoch=1,error=-3.247
# >epoch=1,error=5.135
# >epoch=1,error=4.440
# >epoch=1,error=10.443
# >epoch=1,error=-2.492
# >epoch=1,error=4.735
# >epoch=1,error=7.354
# >epoch=1,error=3.231
# >epoch=1,error=14.530
# >epoch=1,error=13.644
# >epoch=1,error=14.516
# >epoch=1,error=22.184
# >epoch=1,error=7.777
# >epoch=1,error=10.851
# >epoch=1,error=7.545
# >epoch=1,error=11.334
# >epoch=1,error=23.074
# >epoch=1,error=24.003
# >epoch=1,error=5.086
# >epoch=1,error=6.300
# >epoch=1,error=5.866
# >epoch=1,error=0.659
# >epoch=1,error=2.533
# >epoch=1,error=-2.061
# >epoch=1,error=-1.556
# >epoch=1,error=-0.812
# >epoch=1,error=16.360
# >epoch=1,error=12.739
# >epoch=1,error=8.051
# >epoch=1,error=13.075
# >epoch=1,error=3.501
# >epoch=1,error=9.292
# >epoch=1,error=4.949
# >epoch=1,error=6.576
# >epoch=1,error=8.013
# >epoch=1,error=20.485
# >epoch=1,error=16.160
# >epoch=1,error=3.662
# >epoch=1,error=18.178
# >epoch=1,error=8.866
# >epoch=1,error=7.094
# >epoch=1,error=19.207
# >epoch=1,error=0.777
# >epoch=1,error=17.808
# >epoch=1,error=12.572
# >epoch=1,error=13.270
# >epoch=1,error=11.534
# >epoch=1,error=15.529
# >epoch=1,error=14.665
# >epoch=1,error=3.717
# >epoch=1,error=16.897
# >epoch=1,error=15.764
# >epoch=1,error=4.131
# >epoch=1,error=3.408
# >epoch=1,error=8.219
# >epoch=1,error=0.195
# >epoch=1,error=16.735
# >epoch=1,error=14.451
# >epoch=1,error=17.561
# >epoch=1,error=21.334
# >epoch=1,error=6.720
# >epoch=1,error=18.554
# >epoch=1,error=11.507
# >epoch=1,error=21.374
# >epoch=1,error=10.029
# >epoch=1,error=8.109
# >epoch=1,error=-2.246
# >epoch=1,error=15.541
# >epoch=1,error=9.716
# >epoch=1,error=22.633
# >epoch=1,error=5.324
# >epoch=1,error=-1.258
# >epoch=1,error=3.247
# >epoch=1,error=4.263
# >epoch=1,error=22.017
# >epoch=1,error=15.031
# >epoch=1,error=10.898
# >epoch=1,error=-1.311
# >epoch=1,error=10.023
# >epoch=1,error=7.825
# >epoch=1,error=0.125
# >epoch=1,error=8.043
# >epoch=1,error=16.302
# >epoch=1,error=20.802
# >epoch=1,error=0.795
# >epoch=1,error=20.183
# >epoch=1,error=18.892
# >epoch=1,error=13.613
# >epoch=1,error=4.772
# >epoch=1,error=11.577
# >epoch=1,error=14.028
# >epoch=1,error=8.702
# >epoch=1,error=12.021
# >epoch=1,error=12.217
# >epoch=1,error=20.508
# >epoch=1,error=18.969
# >epoch=1,error=6.537
# >epoch=1,error=16.675
# >epoch=1,error=13.493
# >epoch=1,error=11.634
# >epoch=1,error=13.056
# >epoch=1,error=6.479
# >epoch=1,error=3.524
# >epoch=1,error=0.977
# >epoch=1,error=8.460
# >epoch=1,error=8.997
# >epoch=1,error=15.786
# >epoch=1,error=-4.078
# >epoch=1,error=10.580
# >epoch=1,error=5.083
# >epoch=1,error=3.599
# >epoch=1,error=12.096
# >epoch=1,error=15.363
# >epoch=1,error=13.990
# >epoch=1,error=14.311
# >epoch=1,error=4.531
# >epoch=1,error=11.640
# >epoch=1,error=7.489
# >epoch=1,error=12.303
# >epoch=1,error=4.730
# >epoch=1,error=7.089
# >epoch=1,error=13.057
# >epoch=1,error=12.355
# >epoch=1,error=5.849
# >epoch=1,error=13.853
# >epoch=1,error=6.946
# >epoch=1,error=1.659
# >epoch=1,error=0.467
# >epoch=1,error=11.087
# >epoch=1,error=22.814
# >epoch=1,error=25.880
# >epoch=1,error=17.490
# >epoch=1,error=15.083
# >epoch=1,error=7.028
# >epoch=1,error=31.371
# >epoch=1,error=10.720
# >epoch=1,error=8.266
# >epoch=1,error=2.776
# >epoch=1,error=-5.964
# >epoch=1,error=-1.324
# >epoch=1,error=-0.495
# >epoch=1,error=7.375
# >epoch=1,error=17.511
# >epoch=1,error=17.171
# >epoch=1,error=25.233
# >epoch=1,error=18.854
# >epoch=1,error=23.817
# >epoch=1,error=0.435
# >epoch=1,error=4.814
# >epoch=1,error=5.208
# >epoch=1,error=0.576
# >epoch=1,error=21.792
# >epoch=1,error=-0.022
# >epoch=1,error=6.376
# >epoch=1,error=4.955
# >epoch=1,error=12.513
# >epoch=1,error=-0.569
# >epoch=1,error=5.113
# >epoch=1,error=4.538
# >epoch=1,error=19.012
# >epoch=1,error=4.082
# >epoch=1,error=9.898
# >epoch=1,error=11.962
# >epoch=1,error=5.044
# >epoch=1,error=10.974
# >epoch=1,error=22.015
# >epoch=1,error=12.504
# >epoch=1,error=12.180
# >epoch=1,error=7.065
# >epoch=1,error=17.988
# >epoch=1,error=1.144
# >epoch=1,error=12.879
# >epoch=1,error=6.116
# >epoch=1,error=3.490
# >epoch=1,error=25.939
# >epoch=1,error=9.982
# >epoch=1,error=8.794
# >epoch=1,error=1.749
# >epoch=1,error=3.708
# >epoch=1,error=9.898
# >epoch=1,error=14.676
# >epoch=1,error=16.466
# >epoch=1,error=5.665
# >epoch=1,error=1.665
# >epoch=1,error=4.320
# >epoch=1,error=13.042
# >epoch=1,error=0.522
# >epoch=1,error=17.157
# >epoch=1,error=21.734
# >epoch=1,error=22.226
# >epoch=1,error=6.165
# >epoch=1,error=-0.853
# >epoch=1,error=6.987
# >epoch=1,error=5.921
# >epoch=1,error=6.132
# >epoch=1,error=-2.706
# >epoch=1,error=13.691
# >epoch=1,error=9.633
# >epoch=1,error=11.913
# >epoch=1,error=24.921
# >epoch=1,error=17.196
# >epoch=1,error=7.440
# >epoch=1,error=19.933
# >epoch=1,error=10.094
# >epoch=1,error=9.211
# >epoch=1,error=2.235
# >epoch=1,error=3.091
# >epoch=1,error=13.891
# >epoch=1,error=13.984
# >epoch=1,error=16.606
# >epoch=1,error=11.832
# >epoch=1,error=1.313
# >epoch=1,error=12.418
# >epoch=1,error=-2.870
# >epoch=1,error=7.050
# >epoch=1,error=13.595
# >epoch=1,error=23.212
# >epoch=1,error=4.387
# >epoch=1,error=6.936
# >epoch=1,error=-2.289
# >epoch=1,error=7.325
# >epoch=1,error=6.394
# >epoch=1,error=14.782
# >epoch=1,error=6.031
# >epoch=1,error=0.556
# >epoch=1,error=10.522
# >epoch=1,error=12.911
# >epoch=1,error=9.789
# >epoch=1,error=8.983
# >epoch=1,error=10.252
# >epoch=1,error=15.061
# >epoch=1,error=15.067
# >epoch=1,error=5.979
# >epoch=1,error=22.893
# >epoch=1,error=5.683
# >epoch=1,error=3.255
# >epoch=1,error=12.422
# >epoch=1,error=9.168
# >epoch=1,error=6.450
# >epoch=1,error=10.830
# >epoch=1,error=4.581
# >epoch=1,error=8.806
# >epoch=1,error=7.286
# >epoch=1,error=19.239
# >epoch=1,error=9.855
# >epoch=1,error=10.090
# >epoch=1,error=15.078
# >epoch=1,error=12.775
# >epoch=1,error=6.347
# >epoch=1,error=-5.488
# >epoch=1,error=4.976
# >epoch=1,error=11.287
# >epoch=1,error=17.200
# >epoch=1,error=-0.751
# >epoch=1,error=13.528
# >epoch=1,error=6.487
# >epoch=1,error=14.465
# >epoch=1,error=9.717
# >epoch=1,error=-1.137
# >epoch=1,error=7.227
# >epoch=1,error=0.130
# >epoch=1,error=13.011
# >epoch=1,error=2.063
# >epoch=1,error=9.240
# >epoch=1,error=22.380
# >epoch=1,error=5.485
# >epoch=1,error=11.222
# >epoch=1,error=4.571
# >epoch=1,error=20.347
# >epoch=1,error=-2.169
# >epoch=1,error=10.008
# >epoch=1,error=18.131
# >epoch=1,error=13.264
# >epoch=1,error=9.663
# >epoch=1,error=7.022
# >epoch=1,error=7.302
# >epoch=1,error=-2.737
# >epoch=1,error=21.053
# >epoch=1,error=14.906
# >epoch=1,error=2.522
# >epoch=1,error=2.330
# >epoch=1,error=3.055
# >epoch=1,error=17.503
# >epoch=1,error=13.859
# >epoch=1,error=1.212
# >epoch=1,error=15.072
# >epoch=1,error=12.447
# >epoch=1,error=3.464
# >epoch=1,error=13.616
# >epoch=1,error=5.192
# >epoch=1,error=17.870
# >epoch=1,error=9.892
# >epoch=1,error=9.895
# >epoch=1,error=5.477
# >epoch=1,error=-3.550
# >epoch=1,error=15.804
# >epoch=1,error=4.719
# >epoch=1,error=5.487
# >epoch=1,error=9.016
# >epoch=1,error=2.036
# >epoch=1,error=-1.184
# >epoch=1,error=3.198
# >epoch=1,error=12.947
# >epoch=1,error=21.265
# >epoch=1,error=3.449
# >epoch=1,error=15.203
# >epoch=1,error=6.141
# >epoch=1,error=3.948
# >epoch=1,error=5.590
# >epoch=1,error=10.738
# >epoch=1,error=-0.732
# >epoch=1,error=14.136
# >epoch=1,error=6.152
# >epoch=1,error=22.860
# >epoch=1,error=13.434
# >epoch=1,error=23.286
# >epoch=1,error=23.181
# >epoch=1,error=15.830
# >epoch=1,error=11.794
# >epoch=1,error=4.104
# >epoch=1,error=10.296
# >epoch=1,error=3.800
# >epoch=1,error=14.850
# >epoch=1,error=14.874
# >epoch=1,error=15.336
# >epoch=1,error=2.118
# >epoch=1,error=24.557
# >epoch=1,error=11.535
# >epoch=1,error=-4.269
# >epoch=1,error=18.127
# >epoch=1,error=25.905
# >epoch=1,error=19.573
# >epoch=1,error=11.452
# >epoch=1,error=10.157
# >epoch=1,error=15.052
# >epoch=1,error=2.744
# >epoch=1,error=7.715
# >epoch=1,error=2.732
# >epoch=1,error=0.439
# >epoch=1,error=14.976
# >epoch=1,error=18.296
# >epoch=1,error=-0.368
# >epoch=1,error=4.946
# >epoch=1,error=7.598
# >epoch=1,error=28.213
# >epoch=1,error=2.591
# >epoch=1,error=10.678
# >epoch=1,error=4.343
# >epoch=1,error=17.080
# >epoch=1,error=-1.847
# >epoch=1,error=5.290
# >epoch=1,error=12.033
# >epoch=1,error=11.384
# >epoch=1,error=4.449
# >epoch=1,error=4.575
# >epoch=1,error=-0.888
# >epoch=1,error=20.966
# >epoch=1,error=9.718
# >epoch=1,error=2.686
# >epoch=1,error=19.647
# >epoch=1,error=3.066
# >epoch=1,error=12.882
# >epoch=1,error=22.928
# >epoch=1,error=14.212
# >epoch=1,error=19.465
# >epoch=1,error=26.909
# >epoch=1,error=3.825
# >epoch=1,error=6.683
# >epoch=1,error=11.792
# >epoch=1,error=5.470
# >epoch=1,error=13.435
# >epoch=1,error=-0.510
# >epoch=1,error=0.702
# >epoch=1,error=11.941
# >epoch=1,error=11.656
# >epoch=1,error=8.260
# >epoch=1,error=1.894
# >epoch=1,error=13.251
# >epoch=1,error=-1.822
# >epoch=1,error=0.354
# >epoch=1,error=2.528
# >epoch=1,error=5.762
# >epoch=2,error=13.458
# >epoch=2,error=18.319
# >epoch=2,error=6.845
# >epoch=2,error=4.990
# >epoch=2,error=13.107
# >epoch=2,error=6.889
# >epoch=2,error=6.183
# >epoch=2,error=10.106
# >epoch=2,error=13.474
# >epoch=2,error=23.008
# >epoch=2,error=8.806
# >epoch=2,error=4.649
# >epoch=2,error=16.157
# >epoch=2,error=15.381
# >epoch=2,error=21.336
# >epoch=2,error=8.065
# >epoch=2,error=9.496
# >epoch=2,error=5.467
# >epoch=2,error=14.086
# >epoch=2,error=6.268
# >epoch=2,error=17.279
# >epoch=2,error=9.110
# >epoch=2,error=20.093
# >epoch=2,error=7.672
# >epoch=2,error=9.257
# >epoch=2,error=-2.551
# >epoch=2,error=10.304
# >epoch=2,error=25.079
# >epoch=2,error=3.909
# >epoch=2,error=9.575
# >epoch=2,error=8.914
# >epoch=2,error=20.917
# >epoch=2,error=-0.084
# >epoch=2,error=6.389
# >epoch=2,error=4.850
# >epoch=2,error=7.713
# >epoch=2,error=9.956
# >epoch=2,error=18.340
# >epoch=2,error=6.976
# >epoch=2,error=10.806
# >epoch=2,error=11.172
# >epoch=2,error=7.412
# >epoch=2,error=12.750
# >epoch=2,error=15.205
# >epoch=2,error=9.551
# >epoch=2,error=13.697
# >epoch=2,error=7.843
# >epoch=2,error=0.064
# >epoch=2,error=13.647
# >epoch=2,error=3.989
# >epoch=2,error=3.620
# >epoch=2,error=15.088
# >epoch=2,error=0.675
# >epoch=2,error=8.021
# >epoch=2,error=-0.122
# >epoch=2,error=4.877
# >epoch=2,error=13.648
# >epoch=2,error=17.263
# >epoch=2,error=25.561
# >epoch=2,error=8.632
# >epoch=2,error=19.321
# >epoch=2,error=9.780
# >epoch=2,error=13.856
# >epoch=2,error=4.914
# >epoch=2,error=16.987
# >epoch=2,error=19.555
# >epoch=2,error=4.320
# >epoch=2,error=2.342
# >epoch=2,error=17.198
# >epoch=2,error=5.388
# >epoch=2,error=15.436
# >epoch=2,error=6.963
# >epoch=2,error=11.543
# >epoch=2,error=16.034
# >epoch=2,error=1.853
# >epoch=2,error=6.627
# >epoch=2,error=-6.665
# >epoch=2,error=15.791
# >epoch=2,error=2.390
# >epoch=2,error=16.080
# >epoch=2,error=-1.012
# >epoch=2,error=6.411
# >epoch=2,error=-1.734
# >epoch=2,error=10.290
# >epoch=2,error=8.939
# >epoch=2,error=22.409
# >epoch=2,error=8.163
# >epoch=2,error=6.592
# >epoch=2,error=11.784
# >epoch=2,error=12.167
# >epoch=2,error=0.183
# >epoch=2,error=29.079
# >epoch=2,error=6.579
# >epoch=2,error=17.320
# >epoch=2,error=14.394
# >epoch=2,error=1.539
# >epoch=2,error=0.614
# >epoch=2,error=0.468
# >epoch=2,error=24.829
# >epoch=2,error=8.919
# >epoch=2,error=7.697
# >epoch=2,error=1.143
# >epoch=2,error=13.807
# >epoch=2,error=22.685
# >epoch=2,error=16.195
# >epoch=2,error=0.080
# >epoch=2,error=6.602
# >epoch=2,error=22.170
# >epoch=2,error=20.138
# >epoch=2,error=8.038
# >epoch=2,error=6.309
# >epoch=2,error=6.119
# >epoch=2,error=16.350
# >epoch=2,error=4.245
# >epoch=2,error=7.926
# >epoch=2,error=18.641
# >epoch=2,error=18.809
# >epoch=2,error=-0.676
# >epoch=2,error=6.440
# >epoch=2,error=5.700
# >epoch=2,error=13.384
# >epoch=2,error=11.711
# >epoch=2,error=4.343
# >epoch=2,error=7.516
# >epoch=2,error=4.314
# >epoch=2,error=4.192
# >epoch=2,error=2.079
# >epoch=2,error=5.498
# >epoch=2,error=2.114
# >epoch=2,error=15.208
# >epoch=2,error=-2.731
# >epoch=2,error=2.637
# >epoch=2,error=5.301
# >epoch=2,error=13.989
# >epoch=2,error=13.669
# >epoch=2,error=7.315
# >epoch=2,error=5.358
# >epoch=2,error=-0.258
# >epoch=2,error=17.352
# >epoch=2,error=2.768
# >epoch=2,error=11.125
# >epoch=2,error=-2.384
# >epoch=2,error=8.001
# >epoch=2,error=11.640
# >epoch=2,error=11.190
# >epoch=2,error=9.726
# >epoch=2,error=-0.715
# >epoch=2,error=2.933
# >epoch=2,error=-1.766
# >epoch=2,error=17.825
# >epoch=2,error=-3.592
# >epoch=2,error=10.584
# >epoch=2,error=10.732
# >epoch=2,error=8.392
# >epoch=2,error=19.966
# >epoch=2,error=22.056
# >epoch=2,error=5.639
# >epoch=2,error=17.973
# >epoch=2,error=12.299
# >epoch=2,error=5.861
# >epoch=2,error=4.566
# >epoch=2,error=-0.191
# >epoch=2,error=12.983
# >epoch=2,error=6.461
# >epoch=2,error=16.562
# >epoch=2,error=22.401
# >epoch=2,error=2.760
# >epoch=2,error=2.599
# >epoch=2,error=15.513
# >epoch=2,error=23.231
# >epoch=2,error=18.979
# >epoch=2,error=5.582
# >epoch=2,error=15.093
# >epoch=2,error=3.316
# >epoch=2,error=7.840
# >epoch=2,error=10.907
# >epoch=2,error=18.861
# >epoch=2,error=4.768
# >epoch=2,error=-1.247
# >epoch=2,error=0.426
# >epoch=2,error=16.783
# >epoch=2,error=12.902
# >epoch=2,error=22.788
# >epoch=2,error=20.042
# >epoch=2,error=8.394
# >epoch=2,error=19.850
# >epoch=2,error=9.349
# >epoch=2,error=2.236
# >epoch=2,error=14.125
# >epoch=2,error=5.132
# >epoch=2,error=17.407
# >epoch=2,error=5.531
# >epoch=2,error=-5.671
# >epoch=2,error=2.805
# >epoch=2,error=20.709
# >epoch=2,error=-3.690
# >epoch=2,error=6.943
# >epoch=2,error=7.341
# >epoch=2,error=3.468
# >epoch=2,error=11.939
# >epoch=2,error=11.212
# >epoch=2,error=4.265
# >epoch=2,error=9.801
# >epoch=2,error=5.284
# >epoch=2,error=12.784
# >epoch=2,error=7.922
# >epoch=2,error=18.652
# >epoch=2,error=-0.205
# >epoch=2,error=-0.828
# >epoch=2,error=8.749
# >epoch=2,error=10.655
# >epoch=2,error=21.761
# >epoch=2,error=28.204
# >epoch=2,error=9.570
# >epoch=2,error=10.993
# >epoch=2,error=10.584
# >epoch=2,error=6.836
# >epoch=2,error=10.878
# >epoch=2,error=19.951
# >epoch=2,error=8.870
# >epoch=2,error=10.367
# >epoch=2,error=16.010
# >epoch=2,error=3.652
# >epoch=2,error=-2.424
# >epoch=2,error=13.688
# >epoch=2,error=1.341
# >epoch=2,error=9.762
# >epoch=2,error=0.327
# ...
# >epoch=39,error=3.620
# >epoch=39,error=15.114
# >epoch=39,error=0.675
# >epoch=39,error=8.021
# >epoch=39,error=-0.122
# >epoch=39,error=4.880
# >epoch=39,error=13.648
# >epoch=39,error=17.263
# >epoch=39,error=25.561
# >epoch=39,error=8.632
# >epoch=39,error=19.321
# >epoch=39,error=10.079
# >epoch=39,error=13.856
# >epoch=39,error=4.914
# >epoch=39,error=16.987
# >epoch=39,error=19.555
# >epoch=39,error=4.320
# >epoch=39,error=2.342
# >epoch=39,error=17.198
# >epoch=39,error=5.388
# >epoch=39,error=15.436
# >epoch=39,error=6.963
# >epoch=39,error=11.543
# >epoch=39,error=16.034
# >epoch=39,error=1.853
# >epoch=39,error=6.627
# >epoch=39,error=-6.665
# >epoch=39,error=15.791
# >epoch=39,error=2.390
# >epoch=39,error=16.080
# >epoch=39,error=-1.012
# >epoch=39,error=6.411
# >epoch=39,error=-1.734
# >epoch=39,error=10.222
# >epoch=39,error=8.939
# >epoch=39,error=22.409
# >epoch=39,error=8.163
# >epoch=39,error=6.592
# >epoch=39,error=11.784
# >epoch=39,error=12.167
# >epoch=39,error=0.183
# >epoch=39,error=29.079
# >epoch=39,error=6.514
# >epoch=39,error=17.329
# >epoch=39,error=14.394
# >epoch=39,error=1.539
# >epoch=39,error=0.614
# >epoch=39,error=0.468
# >epoch=39,error=24.829
# >epoch=39,error=8.919
# >epoch=39,error=7.697
# >epoch=39,error=1.143
# >epoch=39,error=13.807
# >epoch=39,error=22.685
# >epoch=39,error=16.195
# >epoch=39,error=0.080
# >epoch=39,error=6.602
# >epoch=39,error=22.170
# >epoch=39,error=20.138
# >epoch=39,error=6.277
# >epoch=39,error=6.291
# >epoch=39,error=4.204
# >epoch=39,error=16.350
# >epoch=39,error=4.245
# >epoch=39,error=7.926
# >epoch=39,error=18.641
# >epoch=39,error=18.809
# >epoch=39,error=-0.676
# >epoch=39,error=6.440
# >epoch=39,error=5.560
# >epoch=39,error=13.384
# >epoch=39,error=11.711
# >epoch=39,error=4.343
# >epoch=39,error=7.517
# >epoch=39,error=4.314
# >epoch=39,error=4.192
# >epoch=39,error=2.079
# >epoch=39,error=5.498
# >epoch=39,error=0.147
# >epoch=39,error=15.208
# >epoch=39,error=-2.731
# >epoch=39,error=2.597
# >epoch=39,error=5.362
# >epoch=39,error=13.988
# >epoch=39,error=13.669
# >epoch=39,error=7.315
# >epoch=39,error=5.358
# >epoch=39,error=-0.258
# >epoch=39,error=17.352
# >epoch=39,error=2.768
# >epoch=39,error=11.125
# >epoch=39,error=-2.384
# >epoch=39,error=7.981
# >epoch=39,error=11.640
# >epoch=39,error=11.190
# >epoch=39,error=9.726
# >epoch=39,error=-0.718
# >epoch=39,error=2.933
# >epoch=39,error=-1.766
# >epoch=39,error=17.825
# >epoch=39,error=-3.592
# >epoch=39,error=10.584
# >epoch=39,error=10.732
# >epoch=39,error=8.392
# >epoch=39,error=19.966
# >epoch=39,error=22.056
# >epoch=39,error=5.639
# >epoch=39,error=17.973
# >epoch=39,error=12.299
# >epoch=39,error=6.088
# >epoch=39,error=4.566
# >epoch=39,error=-0.191
# >epoch=39,error=12.983
# >epoch=39,error=6.461
# >epoch=39,error=16.562
# >epoch=39,error=22.401
# >epoch=39,error=2.760
# >epoch=39,error=2.599
# >epoch=39,error=15.513
# >epoch=39,error=23.231
# >epoch=39,error=18.979
# >epoch=39,error=5.582
# >epoch=39,error=15.093
# >epoch=39,error=3.357
# >epoch=39,error=7.840
# >epoch=39,error=10.907
# >epoch=39,error=18.861
# >epoch=39,error=2.837
# >epoch=39,error=-1.247
# >epoch=39,error=0.426
# >epoch=39,error=16.783
# >epoch=39,error=12.902
# >epoch=39,error=22.788
# >epoch=39,error=20.042
# >epoch=39,error=8.394
# >epoch=39,error=19.850
# >epoch=39,error=9.349
# >epoch=39,error=2.236
# >epoch=39,error=14.125
# >epoch=39,error=4.464
# >epoch=39,error=17.407
# >epoch=39,error=5.531
# >epoch=39,error=-5.671
# >epoch=39,error=2.805
# >epoch=39,error=20.709
# >epoch=39,error=-3.690
# >epoch=39,error=6.943
# >epoch=39,error=7.341
# >epoch=39,error=3.468
# >epoch=39,error=11.939
# >epoch=39,error=11.212
# >epoch=39,error=4.265
# >epoch=39,error=9.801
# >epoch=39,error=5.284
# >epoch=39,error=12.784
# >epoch=39,error=7.922
# >epoch=39,error=18.652
# >epoch=39,error=-0.205
# >epoch=39,error=-0.536
# >epoch=39,error=8.749
# >epoch=39,error=10.655
# >epoch=39,error=21.761
# >epoch=39,error=28.204
# >epoch=39,error=9.570
# >epoch=39,error=10.993
# >epoch=39,error=10.584
# >epoch=39,error=6.836
# >epoch=39,error=10.878
# >epoch=39,error=19.951
# >epoch=39,error=8.869
# >epoch=39,error=10.365
# >epoch=39,error=16.010
# >epoch=39,error=3.652
# >epoch=39,error=-2.424
# >epoch=39,error=13.688
# >epoch=39,error=1.341
# >epoch=39,error=9.762
# >epoch=39,error=0.327
# >epoch=39,error=3.174
# >epoch=39,error=2.517
# >epoch=39,error=6.248
# >epoch=39,error=5.018
# >epoch=39,error=13.248
# >epoch=39,error=16.816
# >epoch=39,error=10.421
# >epoch=39,error=13.087
# >epoch=39,error=16.205
# >epoch=39,error=3.033
# >epoch=39,error=10.816
# >epoch=39,error=17.674
# >epoch=39,error=3.119
# >epoch=39,error=12.459
# >epoch=39,error=14.327
# >epoch=39,error=15.552
# >epoch=39,error=19.270
# >epoch=39,error=11.148
# >epoch=39,error=3.635
# >epoch=39,error=10.040
# >epoch=39,error=21.406
# >epoch=39,error=4.793
# >epoch=39,error=14.732
# >epoch=39,error=11.524
# >epoch=39,error=10.549
# >epoch=39,error=7.219
# >epoch=39,error=19.879
# >epoch=39,error=10.787
# >epoch=39,error=17.545
# >epoch=39,error=-2.816
# >epoch=39,error=10.108
# >epoch=39,error=25.997
# >epoch=39,error=9.778
# >epoch=39,error=-8.127
# >epoch=39,error=-0.075
# >epoch=39,error=15.979
# >epoch=39,error=13.681
# >epoch=39,error=7.669
# >epoch=39,error=11.619
# >epoch=39,error=13.060
# >epoch=39,error=9.141
# >epoch=39,error=1.863
# >epoch=39,error=25.013
# >epoch=39,error=15.191
# >epoch=39,error=-4.025
# >epoch=39,error=9.803
# >epoch=39,error=6.946
# >epoch=39,error=1.127
# >epoch=39,error=5.238
# >epoch=39,error=4.367
# >epoch=39,error=5.593
# >epoch=39,error=19.145
# >epoch=39,error=22.780
# >epoch=39,error=-2.647
# >epoch=39,error=21.240
# >epoch=39,error=4.950
# >epoch=39,error=23.395
# >epoch=39,error=8.267
# >epoch=39,error=3.380
# >epoch=39,error=4.882
# >epoch=39,error=19.173
# >epoch=39,error=15.832
# >epoch=39,error=16.282
# >epoch=39,error=5.778
# >epoch=39,error=18.520
# >epoch=39,error=18.833
# >epoch=39,error=4.935
# >epoch=39,error=11.534
# >epoch=39,error=2.880
# >epoch=39,error=7.547
# >epoch=39,error=14.229
# >epoch=39,error=7.470
# >epoch=39,error=15.025
# >epoch=39,error=6.045
# >epoch=39,error=6.469
# >epoch=39,error=7.470
# >epoch=39,error=14.021
# >epoch=39,error=-0.975
# >epoch=39,error=15.443
# >epoch=39,error=9.151
# >epoch=39,error=4.126
# >epoch=39,error=5.218
# >epoch=39,error=-3.615
# >epoch=39,error=13.078
# >epoch=39,error=3.291
# >epoch=39,error=9.738
# >epoch=39,error=8.664
# >epoch=39,error=26.280
# >epoch=39,error=2.088
# >epoch=39,error=6.668
# >epoch=39,error=22.395
# >epoch=39,error=14.928
# >epoch=39,error=16.641
# >epoch=39,error=7.814
# >epoch=39,error=8.855
# >epoch=39,error=15.147
# >epoch=39,error=3.081
# >epoch=39,error=12.977
# >epoch=39,error=2.117
# >epoch=39,error=8.762
# >epoch=39,error=-2.077
# >epoch=39,error=12.941
# >epoch=39,error=15.279
# >epoch=39,error=3.955
# >epoch=39,error=5.446
# >epoch=39,error=-1.643
# >epoch=39,error=-4.650
# >epoch=39,error=18.655
# >epoch=39,error=11.572
# >epoch=39,error=20.559
# >epoch=39,error=20.072
# >epoch=39,error=6.939
# >epoch=39,error=6.312
# >epoch=39,error=5.896
# >epoch=39,error=3.504
# >epoch=39,error=9.864
# >epoch=39,error=9.260
# >epoch=39,error=12.434
# >epoch=39,error=8.937
# >epoch=39,error=-0.326
# >epoch=39,error=21.299
# >epoch=39,error=26.222
# >epoch=39,error=-5.871
# >epoch=39,error=11.809
# >epoch=39,error=28.128
# >epoch=39,error=8.723
# >epoch=39,error=10.065
# >epoch=39,error=4.158
# >epoch=39,error=4.481
# >epoch=39,error=-1.510
# >epoch=39,error=10.525
# >epoch=39,error=-5.121
# >epoch=39,error=4.953
# >epoch=39,error=2.657
# >epoch=39,error=6.203
# >epoch=39,error=-0.146
# >epoch=39,error=18.794
# >epoch=39,error=5.922
# >epoch=39,error=6.648
# >epoch=39,error=4.031
# >epoch=39,error=9.841
# >epoch=39,error=3.622
# >epoch=39,error=11.331
# >epoch=39,error=0.168
# >epoch=39,error=20.066
# >epoch=39,error=26.511
# >epoch=39,error=18.750
# >epoch=39,error=14.729
# >epoch=39,error=13.319
# >epoch=39,error=5.576
# >epoch=39,error=-3.788
# >epoch=39,error=12.195
# >epoch=39,error=-1.607
# >epoch=39,error=-2.316
# >epoch=39,error=1.145
# >epoch=39,error=-4.113
# >epoch=39,error=0.898
# >epoch=39,error=-0.736
# >epoch=39,error=26.844
# >epoch=39,error=11.364
# >epoch=39,error=7.698
# >epoch=39,error=1.451
# >epoch=39,error=18.221
# >epoch=39,error=12.719
# >epoch=39,error=6.473
# >epoch=39,error=9.210
# >epoch=39,error=-0.636
# >epoch=39,error=22.513
# >epoch=39,error=9.935
# >epoch=39,error=5.031
# >epoch=39,error=9.297
# >epoch=39,error=-0.078
# >epoch=39,error=12.397
# >epoch=39,error=-5.079
# >epoch=39,error=7.002
# >epoch=39,error=9.398
# >epoch=39,error=20.546
# >epoch=39,error=-4.963
# >epoch=39,error=3.973
# >epoch=39,error=4.104
# >epoch=39,error=3.057
# >epoch=39,error=6.997
# >epoch=39,error=8.695
# >epoch=39,error=5.527
# >epoch=39,error=12.752
# >epoch=39,error=2.824
# >epoch=39,error=7.762
# >epoch=39,error=4.590
# >epoch=39,error=10.526
# >epoch=39,error=8.191
# >epoch=39,error=10.324
# >epoch=39,error=12.394
# >epoch=39,error=-1.505
# >epoch=39,error=11.197
# >epoch=39,error=0.062
# >epoch=39,error=4.209
# >epoch=39,error=18.203
# >epoch=39,error=8.455
# >epoch=39,error=0.309
# >epoch=39,error=1.997
# >epoch=39,error=0.320
# >epoch=39,error=13.290
# >epoch=39,error=-2.128
# >epoch=39,error=2.122
# >epoch=39,error=2.127
# >epoch=39,error=8.010
# >epoch=39,error=7.773
# >epoch=39,error=1.451
# >epoch=39,error=7.759
# >epoch=39,error=8.912
# >epoch=39,error=14.154
# >epoch=39,error=11.009
# >epoch=39,error=7.809
# >epoch=39,error=4.608
# >epoch=39,error=3.129
# >epoch=39,error=1.778
# >epoch=39,error=5.839
# >epoch=39,error=3.744
# >epoch=39,error=10.377
# >epoch=39,error=17.311
# >epoch=39,error=15.531
# >epoch=39,error=8.182
# >epoch=39,error=-4.263
# >epoch=39,error=9.437
# >epoch=39,error=16.502
# >epoch=39,error=30.678
# >epoch=39,error=15.811
# >epoch=39,error=3.597
# >epoch=39,error=-2.892
# >epoch=39,error=14.672
# >epoch=39,error=-1.885
# >epoch=39,error=11.167
# >epoch=39,error=5.862
# >epoch=39,error=25.120
# >epoch=39,error=14.137
# >epoch=39,error=8.166
# >epoch=39,error=14.639
# >epoch=39,error=9.447
# >epoch=39,error=1.980
# >epoch=39,error=7.756
# >epoch=39,error=6.213
# >epoch=39,error=18.161
# >epoch=39,error=13.041
# >epoch=39,error=3.740
# >epoch=39,error=6.724
# >epoch=39,error=15.178
# >epoch=39,error=24.636
# >epoch=39,error=12.301
# >epoch=39,error=16.475
# >epoch=39,error=-1.721
# >epoch=39,error=5.818
# >epoch=39,error=4.813
# >epoch=39,error=10.618
# >epoch=39,error=8.892
# >epoch=39,error=14.008
# >epoch=39,error=15.042
# >epoch=39,error=16.840
# >epoch=39,error=4.427
# >epoch=39,error=4.916
# >epoch=39,error=15.732
# >epoch=39,error=-0.720
# >epoch=39,error=13.648
# >epoch=39,error=-3.610
# >epoch=39,error=4.735
# >epoch=39,error=8.533
# >epoch=39,error=1.638
# >epoch=39,error=13.081
# >epoch=39,error=3.376
# >epoch=39,error=15.861
# >epoch=39,error=17.648
# >epoch=39,error=2.665
# >epoch=39,error=9.182
# >epoch=39,error=6.769
# >epoch=39,error=14.270
# >epoch=39,error=11.140
# >epoch=39,error=2.115
# >epoch=39,error=13.922
# >epoch=39,error=10.920
# >epoch=39,error=6.107
# >epoch=39,error=8.250
# >epoch=39,error=-0.956
# >epoch=39,error=1.557
# >epoch=39,error=1.566
# >epoch=39,error=15.150
# >epoch=39,error=2.309
# >epoch=39,error=12.759
# >epoch=39,error=13.176
# >epoch=39,error=5.963
# >epoch=39,error=15.126
# >epoch=39,error=10.521
# >epoch=39,error=7.711
# >epoch=39,error=26.848
# >epoch=39,error=16.391
# >epoch=39,error=14.421
# >epoch=39,error=2.064
# >epoch=39,error=16.109
# >epoch=39,error=8.074
# >epoch=39,error=4.255
# >epoch=39,error=7.576
# >epoch=39,error=8.489
# >epoch=39,error=-2.048
# >epoch=39,error=23.410
# >epoch=39,error=9.641
# >epoch=39,error=-0.717
# >epoch=39,error=24.615
# >epoch=39,error=12.624
# >epoch=39,error=-4.727
# >epoch=39,error=-2.303
# >epoch=39,error=3.188
# >epoch=39,error=-2.040
# >epoch=39,error=16.211
# >epoch=39,error=16.998
# >epoch=39,error=10.572
# >epoch=39,error=18.641
# >epoch=39,error=8.790
# >epoch=39,error=16.324
# >epoch=39,error=17.642
# >epoch=39,error=15.360
# >epoch=39,error=1.658
# >epoch=39,error=11.684
# >epoch=39,error=25.214
# >epoch=39,error=1.826
# >epoch=39,error=15.801
# >epoch=39,error=2.628
# >epoch=39,error=18.961
# >epoch=39,error=5.547
# >epoch=39,error=4.422
# >epoch=39,error=14.715
# >epoch=39,error=20.818
# >epoch=39,error=11.948
# >epoch=39,error=0.495
# >epoch=39,error=21.106
# >epoch=39,error=9.688
# >epoch=39,error=8.965
# >epoch=39,error=-3.108
# >epoch=39,error=3.355
# >epoch=39,error=14.261
# >epoch=39,error=23.757
# >epoch=39,error=6.447
# >epoch=39,error=9.491
# >epoch=39,error=9.574
# >epoch=39,error=6.972
# >epoch=39,error=14.434
# >epoch=39,error=10.668
# >epoch=39,error=11.946
# >epoch=39,error=-2.268
# >epoch=39,error=16.945
# >epoch=39,error=8.219
# >epoch=39,error=22.656
# >epoch=39,error=7.317
# >epoch=39,error=2.278
# >epoch=39,error=3.109
# >epoch=39,error=6.222
# >epoch=39,error=18.961
# >epoch=39,error=25.708
# >epoch=39,error=18.829
# >epoch=39,error=8.619
# >epoch=39,error=19.346
# >epoch=39,error=7.292
# >epoch=39,error=5.703
# >epoch=39,error=10.945
# >epoch=39,error=-1.220
# >epoch=39,error=4.096
# >epoch=39,error=10.080
# >epoch=39,error=6.790
# >epoch=39,error=-4.248
# >epoch=39,error=12.579
# >epoch=39,error=21.392
# >epoch=39,error=3.663
# >epoch=39,error=13.158
# >epoch=39,error=-0.694
# >epoch=39,error=13.637
# >epoch=39,error=9.607
# >epoch=39,error=2.123
# >epoch=39,error=7.417
# >epoch=39,error=15.337
# >epoch=39,error=-1.497
# >epoch=39,error=-7.346
# >epoch=39,error=4.255
# >epoch=39,error=3.741
# >epoch=39,error=12.021
# >epoch=39,error=10.155
# >epoch=39,error=9.855
# >epoch=39,error=17.669
# >epoch=39,error=14.381
# >epoch=39,error=4.517
# >epoch=39,error=15.639
# >epoch=39,error=17.540
# >epoch=39,error=5.303
# >epoch=39,error=2.178
# >epoch=39,error=-3.247
# >epoch=39,error=5.135
# >epoch=39,error=4.440
# >epoch=39,error=10.443
# >epoch=39,error=-1.791
# >epoch=39,error=4.735
# >epoch=39,error=7.354
# >epoch=39,error=1.477
# >epoch=39,error=14.530
# >epoch=39,error=13.644
# >epoch=39,error=14.516
# >epoch=39,error=22.184
# >epoch=39,error=7.777
# >epoch=39,error=10.851
# >epoch=39,error=7.545
# >epoch=39,error=11.334
# >epoch=39,error=23.074
# >epoch=39,error=24.003
# >epoch=39,error=5.086
# >epoch=39,error=6.300
# >epoch=39,error=5.866
# >epoch=39,error=0.659
# >epoch=39,error=0.542
# >epoch=39,error=-2.061
# >epoch=39,error=-1.556
# >epoch=39,error=-0.812
# >epoch=39,error=16.360
# >epoch=39,error=12.739
# >epoch=39,error=8.051
# >epoch=39,error=13.075
# >epoch=39,error=3.501
# >epoch=39,error=9.292
# >epoch=39,error=4.949
# >epoch=39,error=6.575
# >epoch=39,error=8.013
# >epoch=39,error=20.485
# >epoch=39,error=16.160
# >epoch=39,error=3.662
# >epoch=39,error=18.178
# >epoch=39,error=8.866
# >epoch=39,error=7.094
# >epoch=39,error=19.207
# >epoch=39,error=0.777
# >epoch=39,error=17.808
# >epoch=39,error=12.572
# >epoch=39,error=13.270
# >epoch=39,error=11.534
# >epoch=39,error=15.530
# >epoch=39,error=14.665
# >epoch=39,error=3.734
# >epoch=39,error=16.897
# >epoch=39,error=15.764
# >epoch=39,error=4.131
# >epoch=39,error=3.408
# >epoch=39,error=8.219
# >epoch=39,error=0.195
# >epoch=39,error=16.735
# >epoch=39,error=14.451
# >epoch=39,error=17.561
# >epoch=39,error=21.334
# >epoch=39,error=6.720
# >epoch=39,error=18.554
# >epoch=39,error=11.507
# >epoch=39,error=21.374
# >epoch=39,error=10.029
# >epoch=39,error=8.109
# >epoch=39,error=-1.545
# >epoch=39,error=15.541
# >epoch=39,error=9.709
# >epoch=39,error=22.633
# >epoch=39,error=5.324
# >epoch=39,error=-1.258
# >epoch=39,error=3.247
# >epoch=39,error=4.268
# >epoch=39,error=22.017
# >epoch=39,error=15.031
# >epoch=39,error=10.890
# >epoch=39,error=-1.311
# >epoch=39,error=10.023
# >epoch=39,error=7.825
# >epoch=39,error=1.894
# >epoch=39,error=8.043
# >epoch=39,error=16.302
# >epoch=39,error=20.802
# >epoch=39,error=0.795
# >epoch=39,error=20.183
# >epoch=39,error=18.892
# >epoch=39,error=13.613
# >epoch=39,error=4.772
# >epoch=39,error=11.577
# >epoch=39,error=14.028
# >epoch=39,error=8.683
# >epoch=39,error=12.021
# >epoch=39,error=12.217
# >epoch=39,error=20.508
# >epoch=39,error=18.969
# >epoch=39,error=6.537
# >epoch=39,error=16.675
# >epoch=39,error=13.492
# >epoch=39,error=11.634
# >epoch=39,error=13.056
# >epoch=39,error=6.475
# >epoch=39,error=3.506
# >epoch=39,error=0.977
# >epoch=39,error=8.460
# >epoch=39,error=8.997
# >epoch=39,error=15.786
# >epoch=39,error=-4.078
# >epoch=39,error=10.580
# >epoch=39,error=5.083
# >epoch=39,error=3.599
# >epoch=39,error=12.096
# >epoch=39,error=15.363
# >epoch=39,error=13.990
# >epoch=39,error=14.311
# >epoch=39,error=4.531
# >epoch=39,error=11.640
# >epoch=39,error=7.489
# >epoch=39,error=12.303
# >epoch=39,error=4.730
# >epoch=39,error=7.089
# >epoch=39,error=13.057
# >epoch=39,error=12.355
# >epoch=39,error=5.849
# >epoch=39,error=13.853
# >epoch=39,error=6.946
# >epoch=39,error=1.659
# >epoch=39,error=0.456
# >epoch=39,error=11.087
# >epoch=39,error=22.813
# >epoch=39,error=25.880
# >epoch=39,error=17.490
# >epoch=39,error=15.083
# >epoch=39,error=7.028
# >epoch=39,error=31.371
# >epoch=39,error=10.720
# >epoch=39,error=8.266
# >epoch=39,error=2.776
# >epoch=39,error=-5.964
# >epoch=39,error=-1.324
# >epoch=39,error=-0.504

# %%
plt.plot(epochs,errors)
plt.xlabel("epochs in 10000's")
plt.ylabel('error')
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-40-d172309e36c1> in <module>
# ----> 1 print(net[0][0].dot(X[0]))
#
# AttributeError: 'dict' object has no attribute 'dot'

# %%
def predict(network, row):
    outputs = forward_propagation(net, row)
    return outputs

# %%
pred=predict(net,np.array([1,0]))
output=np.argmax(pred)
print(output)

# %%
print_network(net)
